# %%
import os
import yaml

import pandas as pd
import geopandas as gpd
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import seaborn as sns
import folium
from folium.plugins import HeatMap

import sklearn
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf

from copy import deepcopy
from datetime import datetime
import requests
import re

# %% [markdown]
# # Dataset Accidents

# %% [markdown]
# ## Téléchargements des datasets
# - Lieux
# - Usagers
# - Caractéristiques
# - Véhicules
#
# Call API, Download csv dans le bon folder

# %%
# Call API Data Accidents
def get_datasets_url(url=None):
    url='https://www.data.gouv.fr/api/1/datasets/53698f4ca3a729239d2036df/'
    r = requests.get(url).json()
    return {el['title']: el['latest'] for el in r['resources'] if el['title'].endswith(".csv") and not el['title'].startswith("vehicules-immatricules") }

lieux_datasets = {i:j for i,j in get_datasets_url().items() if i.startswith("lieux")}
usagers_datasets = {i:j for i,j in get_datasets_url().items() if i.startswith("usagers")}
car_datasets = {i:j for i,j in get_datasets_url().items() if i.startswith("car")}
vehicule_datasets = {i:j for i,j in get_datasets_url().items() if i.startswith("vehicule")}

all_urls = [lieux_datasets, usagers_datasets, car_datasets,vehicule_datasets]

### download csvs if not already

for url_dict in all_urls:
    for file_name, url in url_dict.items():
        file_name = '../raw_data/' + file_name
        if not os.path.exists(file_name):
            response = requests.get(url)
            if response.status_code == 200:
                with open(file_name, 'wb') as f:
                    f.write(response.content)

### check datasets

folder = "../raw_data/"
os.listdir(folder)
# Out:
# ['lieux_2017.csv',
#  'vehicules_2018.csv',
#  'usagers_2006.csv',
#  'usagers_2012.csv',
#  'usagers_2013.csv',
#  'usagers_2007.csv',
#  'vehicules_2019.csv',
#  'lieux_2016.csv',
#  'lieux_2014.csv',
#  'usagers_2011.csv',
#  'usagers_2005.csv',
#  'usagers_2010.csv',
#  'usagers.csv',
#  'lieux_2015.csv',
#  'lieux_2011.csv',
#  'lieux_2005.csv',
#  'vehicules_2022.csv',
#  'usagers_2014.csv',
#  '.DS_Store',
#  'usagers_2015.csv',
#  'lieux_2010.csv',
#  'lieux_2006.csv',
#  'lieux_2012.csv',
#  'vehicules_2009.csv',
#  'vehicules_2021.csv',
#  'lieux.csv',
#  'usagers_2017.csv',
#  'caracteristiques-2017.csv',
#  'Flux',
#  'usagers_2016.csv',
#  'vehicules_2020.csv',
#  'vehicules_2008.csv',
#  'lieux_2013.csv',
#  'lieux_2007.csv',
#  'lieux-2021.csv',
#  'usagers-2018.csv',
#  'caracteristiques_2018.csv',
#  'caracteristiques_2019.csv',
#  'usagers-2019.csv',
#  'lieux-2020.csv',
#  'lieux-2022.csv',
#  'usagers-2022.csv',
#  'caracteristiques_2022.csv',
#  'vehi.csv',
#  'vehicules-2017.csv',
#  'lieux-2018.csv',
#  'usagers-2021.csv',
#  'caracteristiques_2009.csv',
#  'caracteristiques_2021.csv',
#  'caracteristiques_2020.csv',
#  'caracteristiques_2008.csv',
#  'usagers-2020.csv',
#  'lieux-2019.csv',
#  'caracteristiques_2011.csv',
#  'caracteristiques_2005.csv',
#  'caracteristiques_2010.csv',
#  'vehicules-2018.csv',
#  'lieux-2017.csv',
#  'caracteristiques_2006.csv',
#  'caracteristiques_2012.csv',
#  'caracteristiques_2013.csv',
#  'caracteristiques_2007.csv',
#  'vehicules-2019.csv',
#  'vehicules-2021.csv',
#  'carcteristiques-2021.csv',
#  'usagers-2017.csv',
#  'caracteristiques_2017.csv',
#  'caracteristiques_2016.csv',
#  'vehicules-2020.csv',
#  'vehicules-2022.csv',
#  'carcteristiques-2022.csv',
#  'caracteristiques_2014.csv',
#  'caracteristiques_2015.csv',
#  'lieux_2022.csv',
#  'vehicules_2005.csv',
#  'vehicules_2011.csv',
#  'Pistes',
#  'vehicules_2010.csv',
#  'lieux_2009.csv',
#  'lieux_2021.csv',
#  'vehicules_2012.csv',
#  'vehicules_2006.csv',
#  'usagers_2018.csv',
#  'caracteristiques-2018.csv',
#  'caracteristiques-2019.csv',
#  'usagers_2019.csv',
#  'vehicules_2007.csv',
#  'vehicules_2013.csv',
#  'lieux_2020.csv',
#  'lieux_2008.csv',
#  'carac.csv',
#  'lieux_2018.csv',
#  'vehicules_2017.csv',
#  'usagers_2021.csv',
#  'usagers_2009.csv',
#  'caracteristiques-2020.csv',
#  'usagers_2008.csv',
#  'usagers_2020.csv',
#  'vehicules_2016.csv',
#  'lieux_2019.csv',
#  'vehicules_2014.csv',
#  'usagers_2022.csv',
#  'vehicules_2015.csv']

# %% [markdown]
# #### Renommage des fichiers

# %%
chemin_fichier_yml = '../config.yml'
chemin_dossier = '../raw_data'


with open (chemin_fichier_yml, 'r') as f:
    config = yaml.safe_load(f)
    rename_config = config.get('rename')

for old_name, new_name in rename_config.items():
    chemin_ancien_fichier = os.path.join(chemin_dossier, old_name)
    chemin_nouveau_fichier = os.path.join(chemin_dossier, new_name)

    if os.path.exists(chemin_ancien_fichier):
        os.rename(chemin_ancien_fichier, chemin_nouveau_fichier)
        print(f"Fichier renommé : {old_name} -> {new_name}")
    else:
        print(f"Fichier non trouvé : {old_name}")
# Out:
# Fichier renommé : caracteristiques-2017.csv -> caracteristiques_2017.csv
# Fichier renommé : caracteristiques-2018.csv -> caracteristiques_2018.csv
# Fichier renommé : caracteristiques-2019.csv -> caracteristiques_2019.csv
# Fichier renommé : caracteristiques-2020.csv -> caracteristiques_2020.csv
# Fichier renommé : carcteristiques-2021.csv -> caracteristiques_2021.csv
# Fichier renommé : carcteristiques-2022.csv -> caracteristiques_2022.csv
# Fichier renommé : lieux-2017.csv -> lieux_2017.csv
# Fichier renommé : lieux-2018.csv -> lieux_2018.csv
# Fichier renommé : lieux-2019.csv -> lieux_2019.csv
# Fichier renommé : lieux-2020.csv -> lieux_2020.csv
# Fichier renommé : lieux-2021.csv -> lieux_2021.csv
# Fichier renommé : lieux-2022.csv -> lieux_2022.csv
# Fichier renommé : usagers-2017.csv -> usagers_2017.csv
# Fichier renommé : usagers-2018.csv -> usagers_2018.csv
# Fichier renommé : usagers-2019.csv -> usagers_2019.csv
# Fichier renommé : usagers-2020.csv -> usagers_2020.csv
# Fichier renommé : usagers-2021.csv -> usagers_2021.csv
# Fichier renommé : usagers-2022.csv -> usagers_2022.csv
# Fichier renommé : vehicules-2017.csv -> vehicules_2017.csv
# Fichier renommé : vehicules-2018.csv -> vehicules_2018.csv
# Fichier renommé : vehicules-2019.csv -> vehicules_2019.csv
# Fichier renommé : vehicules-2020.csv -> vehicules_2020.csv
# Fichier renommé : vehicules-2021.csv -> vehicules_2021.csv
# Fichier renommé : vehicules-2022.csv -> vehicules_2022.csv

# %% [markdown]
# #### Concaténation des 4 types de fichiers

# %%
# Passer par fonction et var env
def concat_files(starting_word):

    chemin_fichier_yml = '../config.yml'
    with open(chemin_fichier_yml, 'r') as f:
        config = yaml.safe_load(f)
        config_sep = config.get('sep')
        config_encoding = config.get('encoding')

    chemin_dossier = '../raw_data/'

    df_concat = pd.DataFrame()
    files = [file for file in os.listdir(chemin_dossier) if file.endswith('.csv') and file.startswith(starting_word)]

    print(files)
    for file in files:
        chemin_fichier = os.path.join(chemin_dossier, file)

        if file in config_sep:
            sep = config_sep[file]
        else:
            sep = ','

        if file in config_encoding:
            encoding = config_encoding[file]
        else:
            encoding = 'utf-8'

        df1 = pd.read_csv(chemin_fichier, sep=sep, encoding=encoding, dtype=str)

        df_concat = pd.concat([df_concat, df1])

    return df_concat

#utiliser yield ?

# %%
carac_df = concat_files("caracteristiques")
lieux_df = concat_files("lieux")
usager_df = concat_files("usagers")
vehi_df = concat_files("vehicules")
# Out:
# ['caracteristiques_2018.csv', 'caracteristiques_2019.csv', 'caracteristiques_2022.csv', 'caracteristiques_2009.csv', 'caracteristiques_2021.csv', 'caracteristiques_2020.csv', 'caracteristiques_2008.csv', 'caracteristiques_2011.csv', 'caracteristiques_2005.csv', 'caracteristiques_2010.csv', 'caracteristiques_2006.csv', 'caracteristiques_2012.csv', 'caracteristiques_2013.csv', 'caracteristiques_2007.csv', 'caracteristiques_2017.csv', 'caracteristiques_2016.csv', 'caracteristiques_2014.csv', 'caracteristiques_2015.csv']
# /var/folders/jg/x3y4bp6n6071zs7rycbnfsyc0000gn/T/ipykernel_91694/28020598.py:29: ParserWarning:
#
# Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# ['lieux_2017.csv', 'lieux_2016.csv', 'lieux_2014.csv', 'lieux_2015.csv', 'lieux_2011.csv', 'lieux_2005.csv', 'lieux_2010.csv', 'lieux_2006.csv', 'lieux_2012.csv', 'lieux.csv', 'lieux_2013.csv', 'lieux_2007.csv', 'lieux_2022.csv', 'lieux_2009.csv', 'lieux_2021.csv', 'lieux_2020.csv', 'lieux_2008.csv', 'lieux_2018.csv', 'lieux_2019.csv']
# ['usagers_2006.csv', 'usagers_2012.csv', 'usagers_2013.csv', 'usagers_2007.csv', 'usagers_2011.csv', 'usagers_2005.csv', 'usagers_2010.csv', 'usagers.csv', 'usagers_2014.csv', 'usagers_2015.csv', 'usagers_2017.csv', 'usagers_2016.csv', 'usagers_2018.csv', 'usagers_2019.csv', 'usagers_2021.csv', 'usagers_2009.csv', 'usagers_2008.csv', 'usagers_2020.csv', 'usagers_2022.csv']
# ['vehicules_2018.csv', 'vehicules_2019.csv', 'vehicules_2022.csv', 'vehicules_2009.csv', 'vehicules_2021.csv', 'vehicules_2020.csv', 'vehicules_2008.csv', 'vehicules_2005.csv', 'vehicules_2011.csv', 'vehicules_2010.csv', 'vehicules_2012.csv', 'vehicules_2006.csv', 'vehicules_2007.csv', 'vehicules_2013.csv', 'vehicules_2017.csv', 'vehicules_2016.csv', 'vehicules_2014.csv', 'vehicules_2015.csv']

# %% [markdown]
# #### Export en .csv

# %%
vehi_df.to_csv('../raw_data/vehi.csv', index=False)
carac_df.to_csv('../raw_data/carac.csv', index=False)
lieux_df.to_csv('../raw_data/lieux.csv', index=False)
usager_df.to_csv('../raw_data/usagers.csv', index=False)

# %% [markdown]
# ## Dataframe Vehicules

# %%
vehi_df.head(2)
# Out:
#         Num_Acc senc catv occutc obs obsm choc manv num_veh id_vehicule motor
# 0  201800000001    0   07    000  00    2    3   01     B01         NaN   NaN
# 1  201800000001    0   07    000  00    2    2   15     A01         NaN   NaN

# %% [markdown]
# Drop columns occutc, num_veh, motor, id_vehicule, senc

# %%
vehi_df_modif = vehi_df.drop(['occutc','motor', 'id_vehicule','senc'], axis=1, inplace=False)

# %% [markdown]
# Cleaning columns obs, obsm, choc, manv,

# %%
"""Converting col obs in int"""
vehi_df_modif['obs'] = vehi_df_modif['obs'].fillna(-1).astype(float).astype(int)

# %%
"""Clean the column 'obs'"""
values_destribution_obs = vehi_df_modif.obs[vehi_df_modif.obs >= 0].value_counts(normalize=True)
# new_values_obs = np.random.choice(values_destribution_obs.index, size = vehi_df_modif['obs'].isna().sum(), p=values_destribution_obs.values)
# vehi_df_modif.loc[vehi_df_modif['obs'].isna(), 'obs'] = new_values_obs
new_values_obs2 = np.random.choice(values_destribution_obs.index, size = (vehi_df_modif['obs'] == -1).sum(), p=values_destribution_obs.values)
vehi_df_modif.loc[vehi_df_modif['obs'] == -1, 'obs'] = new_values_obs2

# %%
"""Converting col obsm in int"""
vehi_df_modif['obsm'] = vehi_df_modif['obsm'].fillna(-1).astype(float).astype(int)

"""Cleaning the column 'obsm'"""
values_destribution_obsm = vehi_df_modif.obsm[vehi_df_modif.obsm >= 0].value_counts(normalize=True)
# new_values_obsm = np.random.choice(values_destribution_obsm.index, size = vehi_df_modif['obsm'].isna().sum(), p=values_destribution_obsm.values)
# vehi_df_modif.loc[vehi_df_modif['obsm'].isna(), 'obsm'] = new_values_obsm
new_values_obsm2 = np.random.choice(values_destribution_obsm.index, size = (vehi_df_modif['obsm'] == -1).sum(), p=values_destribution_obsm.values)
vehi_df_modif.loc[vehi_df_modif['obsm'] == -1, 'obsm'] = new_values_obsm2

# %%
"""Converting col choc in int"""
vehi_df_modif['choc'] = vehi_df_modif['choc'].fillna(-1).astype(float).astype(int)

"""Clean the column 'choc'"""
values_destribution_choc = vehi_df_modif.choc[vehi_df_modif.choc >= 0].value_counts(normalize=True)
# new_values_choc = np.random.choice(values_destribution_choc.index, size = vehi_df_modif['choc'].isna().sum(), p=values_destribution_choc.values)
# vehi_df_modif.loc[vehi_df_modif['choc'].isna(), 'choc'] = new_values_choc
new_values_choc2 = np.random.choice(values_destribution_choc.index, size = (vehi_df_modif['choc'] == -1).sum(), p=values_destribution_choc.values)
vehi_df_modif.loc[vehi_df_modif['choc'] == -1, 'choc'] = new_values_choc2

# %%
"""Converting col manv in int"""
vehi_df_modif['manv'] = vehi_df_modif['manv'].fillna(0).astype(float).astype(int)

"""Clean the column 'manv'"""""
values_destribution_manv = vehi_df_modif.manv[vehi_df_modif.manv > 0].value_counts(normalize=True)
new_values_manv = np.random.choice(values_destribution_manv.index, size = vehi_df_modif['manv'].isna().sum(), p=values_destribution_manv.values)
vehi_df_modif.loc[vehi_df_modif['manv'].isna(), 'manv'] = new_values_manv
new_values_manv2 = np.random.choice(values_destribution_manv.index, size = (vehi_df_modif['manv'] == -1).sum(), p=values_destribution_manv.values)
vehi_df_modif.loc[vehi_df_modif['manv'] == -1, 'manv'] = new_values_manv2
new_values_manv3 = np.random.choice(values_destribution_manv.index, size = (vehi_df_modif['manv'] == 0).sum(), p=values_destribution_manv.values)
vehi_df_modif.loc[vehi_df_modif['manv'] == 0, 'manv'] = new_values_manv3

# %%
vehi_df_modif['catv'].value_counts(), vehi_df_modif['catv'].isna().sum()
# Out:
# (07     1016821
#  7       220813
#  33      144087
#  10      107333
#  02       87631
#  30       77039
#  01       67929
#  32       41609
#  31       40339
#  05       21816
#  34       21166
#  1        20956
#  14       19832
#  15       17301
#  17       15954
#  2        14082
#  37       12969
#  99        8283
#  13        7624
#  04        7463
#  03        5779
#  50        5116
#  21        4177
#  38        3496
#  36        2574
#  40        2305
#  3         2293
#  20        2150
#  18        2075
#  43        1995
#  80        1793
#  0         1030
#  16         890
#  60         754
#  35         527
#  39         503
#  09         300
#  19         183
#  08         120
#  42          83
#  12          79
#  41          57
#  06          39
#  11          17
#   -1         13
#  Name: catv, dtype: int64,
#  0)

# %%
# Remplacer '02' par '2', et espaces devant chiffres
vehi_df_modif['catv'] = vehi_df['catv'].apply(lambda x: str(int(x.strip())) if x.strip().replace('-', '').isdigit() else x)

# %%
vehi_df_modif['catv'] = vehi_df_modif['catv'].astype(int)

values_destribution_catv = vehi_df_modif['catv'][vehi_df_modif['catv'] > -1].value_counts(normalize=True)
new_values_catv = np.random.choice(values_destribution_catv.index, size = (vehi_df_modif['catv'] == -1).sum(), p=values_destribution_catv.values)
vehi_df_modif.loc[vehi_df_modif['catv'] == -1, 'catv'] = new_values_catv
# Remplacer les -1 par la distribution

# %%
vehi_df_modif['catv'].value_counts()
# Out:
# 7     1237643
# 33     144087
# 10     107335
# 2      101713
# 1       88885
# 30      77041
# 32      41609
# 31      40339
# 5       21816
# 34      21166
# 14      19832
# 15      17301
# 17      15954
# 37      12969
# 99       8283
# 3        8072
# 13       7624
# 4        7463
# 50       5116
# 21       4177
# 38       3496
# 36       2574
# 40       2305
# 20       2150
# 18       2075
# 43       1995
# 80       1793
# 0        1030
# 16        890
# 60        754
# 35        527
# 39        503
# 9         300
# 19        183
# 8         120
# 42         83
# 12         79
# 41         57
# 6          39
# 11         17
# Name: catv, dtype: int64

# %%
vehi_df_modif.head(2)
# Out:
#         Num_Acc  catv  obs  obsm  choc  manv num_veh
# 0  201800000001     7    0     2     3     1     B01
# 1  201800000001     7    0     2     2    15     A01

# %% [markdown]
# Export en .csv

# %%
vehi_df_modif.to_csv('../clean_data/vehicules_clean.csv', index=False)

# %% [markdown]
# ## Dataset Caracteristiques

# %%
carac_df.head(2)
# Out:
#         Num_Acc  an mois jour  hrmn lum agg int atm col  com  \
# 0  201800000001  18    1   24  1505   1   1   4   1   1  005
# 1  201800000002  18    2   12  1015   1   2   7   7   7  011
#
#                         adr gps      lat     long  dep Accident_Id
# 0    route des Ansereuilles   M  5055737  0294992  590         NaN
# 1  Place du général de Gaul   M  5052936  0293151  590         NaN

# %% [markdown]
# Drop des col gps et accidents_id

# %%
carac_df_modif = carac_df.drop(['gps', 'Accident_Id'], axis=1, inplace=False)

# %% [markdown]
# Formatage des 4 col date en une (optionnel)

# %%
# def process_dates(df):
#     # Vérifier les dates invalides
#     invalid_dates = df[(df['jour'] > 31) | ((df['mois'] == 2) & (df['jour'] > 29)) | ((df['mois'].isin([4, 6, 9, 11])) & (df['jour'] > 30))]
#     df = df.drop(invalid_dates.index)

#     # Créer la colonne 'date'
#     df['date'] = pd.to_datetime(df['an'].astype(str).str.zfill(2)
#                                 + df['mois'].astype(str).str.zfill(2)
#                                 + df['jour'].astype(str).str.zfill(2)
#                                 + df['hrmn'].astype(str).str.zfill(4),
#                                 format='%y%m%d%H%M', errors='coerce')

#     df = df.drop(columns=['an', 'mois', 'jour', 'hrmn'])
#     return df

# # Utiliser la fonction sur carac_df_modif
# carac_df_modif = process_dates(carac_df_modif)

# %% [markdown]
# Cleaning des col Num_ACC, com, lum, int, col, atm

# %%
"""Drop Na de Num_Acc, com"""
carac_df_modif = carac_df_modif.dropna(subset=['Num_Acc','com'])

# %%
"""Converting col lum as int"""
carac_df_modif['lum'] = carac_df_modif['lum'].astype(int)

"""Clean the column 'lum'"""
values_destribution_lum = carac_df_modif.lum[carac_df_modif['lum'] >= 0].value_counts(normalize=True)
new_values_lum = np.random.choice(values_destribution_lum.index, size = (carac_df_modif['lum'] == -1).sum(), p=values_destribution_lum.values)
carac_df_modif.loc[carac_df_modif['lum'] == -1, 'lum'] = new_values_lum

# %%
"""Converting col int as int"""
carac_df_modif['int'] = carac_df_modif['int'].astype(int)

"""Delete wrong values column int"""
carac_df_modif = carac_df_modif.loc[carac_df_modif['int'] != -1]

# %%
"""Converting col col as int"""
carac_df_modif = carac_df_modif.dropna(subset=['col'])
carac_df_modif['col'] = carac_df_modif['col'].astype(int)

"""Clean the column 'col'"""
most_frequent = carac_df_modif['col'].mode()[0]
carac_df_modif['col'] = carac_df_modif['col'].replace(-1, most_frequent)

# %%
"""Converting col atm as int"""
carac_df_modif = carac_df_modif.dropna(subset=['atm'])
carac_df_modif['atm'] = carac_df_modif['atm'].astype(int)

"""Clean the column 'atm'"""
most_frequent = carac_df_modif['atm'].mode()[0]
carac_df_modif['atm'] = carac_df_modif['atm'].replace(-1, most_frequent)

# %%
carac_df_modif.isna().sum()
# Out:
# Num_Acc         0
# an              0
# mois            0
# jour            0
# hrmn            0
# lum             0
# agg             0
# int             0
# atm             0
# col             0
# com             0
# adr        143270
# lat        487017
# long       487021
# dep             0
# dtype: int64

# %%
carac_df_modif.head(2)
# Out:
#         Num_Acc  an mois jour  hrmn  lum agg  int  atm  col  com  \
# 0  201800000001  18    1   24  1505    1   1    4    1    1  005
# 1  201800000002  18    2   12  1015    1   2    7    7    7  011
#
#                         adr      lat     long  dep
# 0    route des Ansereuilles  5055737  0294992  590
# 1  Place du général de Gaul  5052936  0293151  590

# %% [markdown]
# Export en .csv

# %%
carac_df_modif.to_csv('../clean_data/caracteristiques_clean.csv', index=False)

# %% [markdown]
# ## Dataset Lieux

# %%
lieux_df.head(2)
# Out:
#         Num_Acc catr voie   v1   v2 circ nbv   pr  pr1 vosp prof plan lartpc  \
# 0  201700000001    3   39  NaN  NaN    2  02  NaN  NaN    2    1    1    000
# 1  201700000002    3   39  NaN  NaN    2  02  NaN  NaN    0    1    0    006
#
#   larrout surf infra situ env1  vma
# 0     070    1     0    1   99  NaN
# 1     010    1   NaN  NaN  NaN  NaN

# %% [markdown]
# Cleaning col circ, nbv, vosp, prof, pr, plan, lartpc, larrout, surf, infra, situ, catr

# %%
lieux_df['circ'].value_counts(), lieux_df['circ'].isna().sum()
# Out:
# (2       2225469
#  2.0     1483646
#  1        626649
#  3        467319
#  1.0      417766
#  3.0      311546
#  0        149898
#  0.0       99932
#   -1       36552
#  -1.0      24368
#  4         20010
#  4.0       13340
#  Name: circ, dtype: int64,
#  7870)

# %%
lieux_df['circ'] = lieux_df['circ'].fillna(2, inplace=False)

# %%
# Conversion des valeurs de type '2.0' en '2' tout en restant en str
lieux_df['circ'] = lieux_df['circ'].astype(str)
lieux_df['circ'] = lieux_df['circ'].apply(lambda x: str(int(float(x))) if x.replace('.', '', 1).lstrip('-').isdigit() and '.' in x else x)

# %%
lieux_df['circ'] = lieux_df['circ'].astype(int)

# %%
#Remplacer les -1 par la distrib
values_destribution_circ = lieux_df['circ'][lieux_df['circ'] > -1].value_counts(normalize=True)
new_values_manv = np.random.choice(values_destribution_circ.index, size = (lieux_df['circ'] == -1).sum(), p=values_destribution_circ.values)
lieux_df.loc[lieux_df['circ'] == -1, 'circ'] = new_values_manv

# %%
#Remplacer les 0 par la distrib
values_destribution_circ = lieux_df['circ'][lieux_df['circ'] > 0].value_counts(normalize=True)
new_values_manv2 = np.random.choice(values_destribution_circ.index, size = (lieux_df['circ'] == 0).sum(), p=values_destribution_circ.values)
lieux_df.loc[lieux_df['circ'] == 0, 'circ'] = new_values_manv2

# %%
lieux_df['circ'].value_counts()
# Out:
# 2    3923977
# 1    1102858
# 3     822274
# 4      35256
# Name: circ, dtype: int64

# %%
lieux_df['nbv'].value_counts(), lieux_df['nbv'].isna().sum()
# Out:
# (02      1607787
#  2.0      981182
#  2        756901
#  01       345204
#  00       326451
#           ...
#  41.0          1
#  33.0          1
#  52.0          1
#  28.0          1
#  86.0          1
#  Name: nbv, Length: 118, dtype: int64,
#  13655)

# %%
lieux_df['nbv'] = lieux_df['nbv'].fillna(2, inplace=False)

# %%
# Conversion des valeurs de type '2.0' en '2' tout en restant en str
lieux_df['nbv'] = lieux_df['nbv'].astype(str)
lieux_df['nbv'] = lieux_df['nbv'].apply(lambda x: str(int(float(x))) if x.replace('.', '', 1).lstrip('-').isdigit() and '.' in x else x)

# Remplacer '02' par '2', et espaces devant chiffres
lieux_df['nbv'] = lieux_df['nbv'].apply(lambda x: str(int(x.strip())) if x.strip().replace('-', '').isdigit() else x)

# %%
lieux_df['nbv'].value_counts()
# Out:
# 2          3359525
# 1           687510
# 4           576740
# 0           570635
# 3           457170
# 6           112185
# 5            64330
# 8            24445
# -1           11150
# 7             8575
# 10            5110
# 9             2655
# 20            1205
# 50             790
# 11             720
# 12             710
# 40             150
# 30             135
# 13              90
# 25              70
# 21              55
# 26              45
# 15              40
# 90              35
# 24              30
# 14              30
# 22              25
# 70              25
# 31              15
# 60              15
# 16              10
# 45              10
# 17              10
# 27              10
# 53              10
# 41               5
# 33               5
# #ERREUR          5
# 52               5
# 44               5
# 28               5
# 91               5
# 86               5
# 54               5
# 76               5
# 99               5
# 42               5
# 65               5
# 36               5
# 18               5
# 84               5
# 39               5
# 29               5
# 62               5
# 23               5
# Name: nbv, dtype: int64

# %%
lieux_df['nbv'] = pd.to_numeric(lieux_df['nbv'], errors='coerce')
lieux_df['nbv'] = lieux_df['nbv'].where(lieux_df['nbv'] <= 4, 2)
lieux_df['nbv'] = lieux_df['nbv'].replace({-1: 2})
# on remplace les valeurs abbérantes(>10) et les valeurs nulles par la valeur la plus fréquente

# %%
lieux_df['nbv'] = lieux_df['circ'].astype(int)

# %%
lieux_df['nbv'].value_counts()
# Out:
# 2    3923977
# 1    1102858
# 3     822274
# 4      35256
# Name: nbv, dtype: int64

# %%
lieux_df['vosp'].value_counts(), lieux_df['vosp'].isna().sum()
# Out:
# (0       3272235
#  0.0     2181490
#  3        103191
#  1         89385
#  3.0       68794
#  1.0       59590
#  2         53559
#  2.0       35706
#   -1        3966
#  -1.0       2644
#  Name: vosp, dtype: int64,
#  13805)

# %%
lieux_df['vosp'] = lieux_df['vosp'].fillna(0, inplace=False)

# %%
# Conversion des valeurs de type '2.0' en '2' tout en restant en str
lieux_df['vosp'] = lieux_df['vosp'].astype(str)
lieux_df['vosp'] = lieux_df['vosp'].apply(lambda x: str(int(float(x))) if x.replace('.', '', 1).lstrip('-').isdigit() and '.' in x else x)

# Remplacer '02' par '2', et espaces devant chiffres
lieux_df['vosp'] = lieux_df['vosp'].apply(lambda x: str(int(x.strip())) if x.strip().replace('-', '').isdigit() else x)

# %%
lieux_df['vosp'] = pd.to_numeric(lieux_df['vosp'], errors='coerce')
lieux_df['vosp'] = lieux_df['vosp'].replace({-1: 0})
# on remplace les valeurs nulles (1k) par la plus fréquente

lieux_df['vosp'].value_counts()
# Out:
# 0    5474140
# 3     171985
# 1     148975
# 2      89265
# Name: vosp, dtype: int64

# %%
lieux_df['prof'].value_counts(), lieux_df['prof'].isna().sum()
# Out:
# (1       2712174
#  1.0     1808116
#  2        504351
#  2.0      336234
#  0        197838
#  0.0      131892
#  3         62421
#  4         47874
#  3.0       41614
#  4.0       31916
#   -1         114
#  -1.0         76
#  Name: prof, dtype: int64,
#  9745)

# %%
lieux_df['prof'] = lieux_df['prof'].fillna(1, inplace=False)

# Conversion des valeurs de type '2.0' en '2' tout en restant en str
lieux_df['prof'] = lieux_df['prof'].astype(str)
lieux_df['prof'] = lieux_df['prof'].apply(lambda x: str(int(float(x))) if x.replace('.', '', 1).lstrip('-').isdigit() and '.' in x else x)

# Remplacer '02' par '2', et espaces devant chiffres
lieux_df['prof'] = lieux_df['prof'].apply(lambda x: str(int(x.strip())) if x.strip().replace('-', '').isdigit() else x)

lieux_df['prof'] = pd.to_numeric(lieux_df['prof'], errors='coerce')
lieux_df['prof'] = lieux_df['prof'].replace({-1: 1,0: 1})
# on remplace les valeurs nulles (65k) par la plus fréquente

# %%
lieux_df['prof'].value_counts()
# Out:
# 1    4859955
# 2     840585
# 3     104035
# 4      79790
# Name: prof, dtype: int64

# %%
lieux_df['pr'].value_counts(), lieux_df['pr'].isna().sum()
# Out:
# (0         794386
#  0.0       300074
#  (1)       270365
#  1         172713
#  2          74913
#             ...
#  2760.0         2
#  1930.0         2
#  3892.0         2
#  1580.0         2
#  1006.0         2
#  Name: pr, Length: 1653, dtype: int64,
#  2377420)

# %%
lieux_df['pr1'].value_counts(), lieux_df['pr1'].isna().sum()
# On drop la colonne pr et la pr1 qui ne sera pas plus utile
# Out:
# (0         972328
#  0.0       396052
#  (1)       274095
#  500       125664
#  200        74003
#             ...
#  2526.0         2
#  1674.0         2
#  1668.0         2
#  2680.0         2
#  3640.0         2
#  Name: pr1, Length: 4635, dtype: int64,
#  2386515)

# %%
lieux_df['plan'].value_counts(), lieux_df['plan'].isna().sum()
# Out:
# (1       2710068
#  1.0     1806712
#  2        298236
#  3        270771
#  0        199251
#  2.0      198824
#  3.0      180514
#  0.0      132834
#  4         45348
#  4.0       30232
#   -1         102
#  -1.0         68
#  Name: plan, dtype: int64,
#  11405)

# %%
lieux_df['plan'] = lieux_df['plan'].fillna(1, inplace=False)

# Conversion des valeurs de type '2.0' en '2' tout en restant en str
lieux_df['plan'] = lieux_df['plan'].astype(str)
lieux_df['plan'] = lieux_df['plan'].apply(lambda x: str(int(float(x))) if x.replace('.', '', 1).lstrip('-').isdigit() and '.' in x else x)

# Remplacer '02' par '2', et espaces devant chiffres
lieux_df['plan'] = lieux_df['plan'].apply(lambda x: str(int(x.strip())) if x.strip().replace('-', '').isdigit() else x)

lieux_df['plan'] = pd.to_numeric(lieux_df['plan'], errors='coerce')
lieux_df['plan'] = lieux_df['plan'].replace({-1: 1,0: 1})
# on remplace les valeurs nulles (65k) par la plus fréquente

# %%
lieux_df['plan'].value_counts()
# Out:
# 1    4860440
# 2     497060
# 3     451285
# 4      75580
# Name: plan, dtype: int64

# %%
lieux_df['lartpc'].value_counts(), lieux_df['lartpc'].isna().sum()
#30% de valeurs nulles on drop la colonne
# Out:
# (000      2276046
#  0.0      1354417
#  0         164687
#  015       102069
#  15.0       61850
#            ...
#  780.0          1
#  295.0          1
#  910.0          1
#  570.0          1
#  680.0          1
#  Name: lartpc, Length: 974, dtype: int64,
#  1370530)

# %%
pd.set_option('display.max_rows', None)
lieux_df['larrout'].value_counts(), lieux_df['larrout'].isna().sum()
# on drop, trop valeurs aberrantes
# Out:
# (000                    863124
#   -1                    747400
#  0.0                    513018
#  060                    228585
#  070                    183276
#  60.0                   133620
#  70.0                   106689
#  080                     83205
#  050                     75354
#  120                     75169
#  100                     68651
#  0                       63633
#  140                     63434
#  090                     55278
#  105                     52407
#  80.0                    48176
#  030                     44808
#  50.0                    43735
#  120.0                   40411
#  040                     39573
#  100.0                   36204
#  035                     35919
#  140.0                   34031
#  065                     33483
#  075                     32673
#  90.0                    31896
#  105.0                   28748
#  30.0                    26427
#  072                     25455
#  40.0                    23073
#  062                     22383
#  210                     22233
#  35.0                    21431
#  150                     21200
#  068                     21141
#  055                     20406
#  65.0                    19484
#  60                      18820
#  75.0                    18818
#  064                     18528
#  110                     17719
#  058                     17517
#  063                     16911
#  061                     16059
#  4                       15807
#  70                      15555
#  066                     15432
#  071                     15411
#  074                     15294
#  073                     14865
#  72.0                    14435
#  045                     13812
#  067                     13404
#  056                     13239
#  62.0                    12849
#  076                     12795
#  130                     12344
#  069                     12222
#  68.0                    12006
#  210.0                   11852
#  55.0                    11668
#  059                     11574
#  057                     11463
#  150.0                   11435
#  078                     11427
#  64.0                    10602
#  085                     10470
#  052                     10431
#  054                     10263
#  58.0                     9963
#  63.0                     9680
#  200                      9386
#  160                      9284
#  61.0                     9258
#  110.0                    9146
#  025                      9120
#  180                      9066
#  053                      9000
#  71.0                     8814
#  66.0                     8766
#  095                      8724
#  74.0                     8682
#  73.0                     8497
#  45.0                     8027
#  077                      7965
#  67.0                     7639
#  56.0                     7523
#  80                       7314
#  76.0                     7288
#  69.0                     6947
#  010                      6942
#  5                        6917
#  048                      6900
#  051                      6837
#  59.0                     6662
#  082                      6606
#  57.0                     6551
#  50                       6536
#  78.0                     6522
#  130.0                    6416
#  52.0                     6024
#  020                      6015
#  85.0                     6011
#  079                      5874
#  54.0                     5842
#  088                      5838
#  125                      5720
#  084                      5658
#  25.0                     5502
#  7                        5452
#  046                      5220
#  042                      5211
#  53.0                     5143
#  3                        5131
#  200.0                    5044
#  90                       4971
#  135                      4949
#  95.0                     4924
#  160.0                    4896
#  047                      4887
#  081                      4848
#  180.0                    4839
#  086                      4821
#  115                      4664
#  049                      4611
#  10.0                     4568
#  77.0                     4541
#  092                      4470
#  108                      4462
#  036                      4449
#  098                      4275
#  043                      4209
#  102                      4187
#  087                      4179
#  038                      4092
#  032                      4062
#  083                      4056
#  096                      4002
#  044                      3897
#  48.0                     3896
#  51.0                     3877
#  093                      3876
#  175                      3837
#  104                      3824
#  091                      3804
#  094                      3795
#  82.0                     3740
#  5,5                      3710
#  089                      3654
#  106                      3626
#  170                      3527
#  20.0                     3483
#  280                      3476
#  30                       3450
#  041                      3363
#  40                       3329
#  79.0                     3323
#  034                      3306
#  037                      3291
#  88.0                     3287
#  097                      3276
#  84.0                     3225
#  103                      3209
#  112                      3061
#  46.0                     3012
#  033                      3003
#  125.0                    3000
#  42.0                     2990
#  75                       2989
#  107                      2953
#  65                       2893
#  240                      2844
#  099                      2832
#  47.0                     2756
#  81.0                     2755
#  86.0                     2741
#  135.0                    2696
#  49.0                     2681
#  144                      2626
#  031                      2553
#  36.0                     2542
#  72                       2540
#  015                      2535
#  35                       2520
#  118                      2509
#  92.0                     2496
#  101                      2457
#  43.0                     2427
#  98.0                     2412
#  115.0                    2406
#  114                      2382
#  87.0                     2366
#  32.0                     2354
#  039                      2316
#  116                      2310
#  83.0                     2308
#  108.0                    2308
#  38.0                     2308
#  96.0                     2253
#  190                      2246
#  44.0                     2218
#  93.0                     2192
#  91.0                     2168
#  145                      2158
#  94.0                     2137
#  102.0                    2133
#  68                       2128
#  109                      2115
#  175.0                    2083
#  62                       2078
#  270                      2062
#  89.0                     2033
#  124                      2014
#  128                      1999
#  220                      1977
#  250                      1973
#  117                      1970
#  55                       1956
#  113                      1956
#  41.0                     1944
#  37.0                     1918
#  170.0                    1918
#  104.0                    1911
#  122                      1877
#  34.0                     1874
#  97.0                     1857
#  106.0                    1854
#  138                      1853
#  64                       1780
#  028                      1779
#  111                      1773
#  280.0                    1764
#  58                       1755
#  33.0                     1746
#  300                      1716
#  15.0                     1632
#  103.0                    1631
#  126                      1617
#  99.0                     1609
#  63                       1604
#  119                      1600
#  132                      1579
#  123                      1565
#  112.0                    1539
#  66                       1522
#  107.0                    1522
#  74                       1519
#  121                      1512
#  6                        1511
#  142                      1495
#  31.0                     1472
#  144.0                    1469
#  240.0                    1461
#  71                       1460
#  61                       1453
#  73                       1433
#  155                      1426
#  136                      1384
#  10,5                     1360
#  14                       1341
#  39.0                     1338
#  56                       1328
#  67                       1317
#  260                      1282
#  118.0                    1281
#  76                       1257
#  148                      1252
#  190.0                    1244
#  127                      1232
#  114.0                    1218
#  134                      1216
#  10                       1205
#  101.0                    1203
#  69                       1201
#  45                       1191
#  165                      1188
#  600                      1175
#  116.0                    1165
#  029                      1140
#  270.0                    1138
#  3,5                      1125
#  57                       1121
#  78                       1116
#  109.0                    1100
#  145.0                    1077
#  59                       1064
#  250.0                    1047
#  117.0                    1045
#  28.0                     1034
#  124.0                    1031
#  220.0                    1028
#  54                       1015
#  113.0                    1014
#  128.0                    1011
#  350                       997
#  700                       989
#  500                       976
#  027                       972
#  85                        969
#  146                       958
#  300.0                     944
#  122.0                     938
#  138.0                     937
#  52                        930
#  137                       924
#  152                       923
#  139                       921
#  95                        897
#  111.0                     892
#  12                        870
#  53                        867
#  141                       836
#  230                       820
#  026                       819
#  129                       814
#  143                       807
#  131                       804
#  126.0                     803
#  119.0                     795
#  132.0                     781
#  13,5                      775
#  123.0                     770
#  77                        769
#  121.0                     758
#  142.0                     750
#  155.0                     749
#  006                       738
#  9                         737
#  48                        719
#  168                       717
#  156                       706
#  260.0                     698
#  133                       697
#  136.0                     696
#  147                       692
#  51                        681
#  510                       680
#  82                        669
#  154                       660
#  148.0                     653
#  29.0                      647
#  600.0                     645
#  400                       625
#  165.0                     622
#  158                       612
#  88                        605
#  245                       605
#  134.0                     604
#  800                       604
#  79                        598
#  127.0                     598
#  25                        578
#  149                       567
#  27.0                      553
#  151                       549
#  84                        547
#  20                        547
#  500.0                     539
#  225                       537
#  700.0                     531
#  153                       526
#  164                       522
#  340                       520
#  350.0                     513
#  001                       510
#  47                        507
#  6.0                       506
#  162                       502
#  42                        489
#  46                        488
#  146.0                     487
#  215                       487
#  185                       486
#  92                        484
#  900                       483
#  024                       480
#  86                        478
#  81                        477
#  26.0                      476
#  195                       467
#  157                       466
#  007                       462
#  152.0                     462
#  139.0                     459
#  510.0                     450
#  023                       444
#  98                        438
#  141.0                     434
#  166                       432
#  137.0                     431
#  230.0                     430
#  36                        429
#  129.0                     426
#  96                        425
#  216                       423
#  38                        420
#  87                        420
#  143.0                     413
#  131.0                     411
#  89                        403
#  172                       399
#  49                        398
#  83                        396
#  310                       395
#  94                        393
#  022                       393
#  93                        392
#  320                       391
#  44                        380
#  43                        379
#  7.0                       376
#  168.0                     373
#  91                        368
#  17,5                      360
#  163                       356
#  32                        354
#  156.0                     349
#  133.0                     348
#  154.0                     345
#  159                       341
#  161                       341
#  34                        340
#  147.0                     338
#  400.0                     335
#  205                       334
#  97                        332
#  800.0                     331
#  174                       328
#  186                       327
#  176                       326
#  225.0                     318
#  005                       318
#  1.0                       316
#  810                       308
#  021                       306
#  245.0                     305
#  182                       304
#  158.0                     303
#  610                       298
#  41                        298
#  013                       297
#  012                       297
#  167                       290
#  37                        286
#  151.0                     286
#  215.0                     283
#  24.0                      281
#  340.0                     280
#  99                        279
#  008                       270
#  149.0                     268
#  315                       265
#  178                       265
#  171                       261
#  900.0                     257
#  33                        256
#  23.0                      255
#  710                       254
#  192                       252
#  184                       249
#  153.0                     249
#  195.0                     243
#  164.0                     243
#  310.0                     240
#  185.0                     239
#  162.0                     238
#  410                       236
#  188                       236
#  173                       235
#  216.0                     232
#  31                        230
#  650                       229
#  177                       229
#  194                       229
#  320.0                     224
#  750                       222
#  22.0                      221
#  157.0                     219
#  515                       216
#  290                       210
#  166.0                     208
#  720                       207
#  39                        206
#  5.0                       205
#  196                       204
#  360                       202
#  198                       199
#  183                       197
#  810.0                     197
#  172.0                     196
#  204                       195
#  15                        193
#  330                       192
#  12.0                      188
#  610.0                     187
#  13.0                      187
#  205.0                     186
#  169                       183
#  8                         183
#  21.0                      180
#  163.0                     179
#  187                       175
#  161.0                     174
#  181                       173
#  174.0                     172
#  159.0                     169
#  176.0                     169
#  014                       168
#  8.0                       167
#  710.0                     166
#  004                       165
#  520                       164
#  208                       162
#  910                       162
#  620                       160
#  011                       159
#  186.0                     158
#  179                       156
#  315.0                     155
#  6,5                       155
#  18                        154
#  410.0                     154
#  28                        152
#  550                       150
#  207                       149
#  182.0                     146
#  178.0                     145
#  018                       144
#  515.0                     144
#  206                       143
#  212                       141
#  14.0                      141
#  171.0                     139
#  640                       139
#  009                       138
#  650.0                     136
#  295                       134
#  560                       133
#  202                       130
#  680                       130
#  167.0                     130
#  720.0                     128
#  235                       128
#  420                       127
#  214                       126
#  199                       126
#  740                       125
#  5,6                       125
#  197                       125
#  184.0                     121
#  191                       121
#  173.0                     120
#  016                       120
#  29                        118
#  192.0                     118
#  194.0                     116
#  218                       115
#  188.0                     114
#  193                       113
#  4.0                       113
#  750.0                     113
#  360.0                     113
#  201                       111
#  017                       111
#  4,5                       110
#  275                       110
#  187.0                     110
#  290.0                     110
#  5,8                       110
#  580                       108
#  660                       108
#  910.0                     108
#  520.0                     106
#  177.0                     106
#  189                       105
#  570                       104
#  690                       103
#  630                       102
#  255                       101
#  196.0                     101
#  590                       101
#  5,4                       100
#  380                       100
#  11.0                       99
#  730                        99
#  003                        99
#  222                        98
#  213                        98
#  183.0                      98
#  370                        97
#  450                        96
#  198.0                      96
#  27                         95
#  620.0                      95
#  330.0                      93
#  780                        92
#  246                        91
#  209                        91
#  550.0                      90
#  204.0                      90
#  7,3                        90
#  760                        89
#  24                         89
#  540                        88
#  181.0                      87
#  390                        87
#  6,2                        85
#  6,3                        85
#  670                        85
#  9.0                        85
#  7,5                        85
#  7,6                        85
#  228                        84
#  305                        83
#  208.0                      83
#  18.0                       82
#  169.0                      82
#  415                        82
#  815                        81
#  295.0                      81
#  820                        81
#  265                        80
#  16.0                       80
#  224                        80
#  680.0                      80
#  179.0                      79
#  21                         79
#  211                        79
#  480                        77
#  560.0                      77
#  234                        77
#  206.0                      77
#  640.0                      76
#  217                        76
#  202.0                      75
#  850                        75
#  212.0                      74
#  715                        73
#  235.0                      72
#  223                        71
#  285                        71
#  915                        71
#  5,2                        70
#  26                         70
#  019                        69
#  203                        69
#  420.0                      68
#  256                        68
#  193.0                      67
#  530                        67
#  17.0                       66
#  275.0                      65
#  740.0                      65
#  5,7                        65
#  226                        65
#  6,4                        65
#  199.0                      64
#  920                        63
#  11                         62
#  221                        61
#  207.0                      61
#  3.0                        60
#  189.0                      60
#  197.0                      60
#  365                        60
#  430                        60
#  219                        59
#  191.0                      59
#  238                        59
#  276                        58
#  630.0                      58
#  880                        58
#  690.0                      57
#  660.0                      57
#  615                        57
#  580.0                      57
#  570.0                      56
#  760.0                      56
#  730.0                      56
#  13                         56
#  218.0                      55
#  5,3                        55
#  325                        55
#  770                        55
#  242                        54
#  255.0                      54
#  450.0                      54
#  815.0                      54
#  370.0                      53
#  222.0                      52
#  540.0                      52
#  252                        52
#  930                        50
#  950                        50
#  6,7                        50
#  3,6                        50
#  3,8                        50
#  6,6                        50
#  214.0                      49
#  227                        49
#  590.0                      49
#  415.0                      48
#  231                        48
#  312                        48
#  780.0                      48
#  715.0                      47
#  990                        46
#  236                        46
#  960                        46
#  380.0                      45
#  224.0                      45
#  4,7                        45
#  002                        45
#  670.0                      45
#  6,8                        45
#  265.0                      45
#  201.0                      44
#  970                        44
#  209.0                      44
#  820.0                      44
#  915.0                      44
#  237                        44
#  480.0                      43
#  257                        43
#  440                        43
#  234.0                      43
#  390.0                      43
#  248                        43
#  229                        43
#  213.0                      42
#  305.0                      42
#  525                        42
#  19.0                       42
#  790                        41
#  830                        41
#  22                         41
#  228.0                      41
#  23                         41
#  232                        41
#  4,8                        40
#  247                        40
#  272                        40
#  860                        40
#  395                        40
#  233                        40
#  254                        39
#  294                        39
#  217.0                      39
#  460                        39
#  530.0                      38
#  615.0                      38
#  17                         38
#  840                        38
#  920.0                      37
#  203.0                      36
#  513                        36
#  211.0                      36
#  226.0                      35
#  7,2                        35
#  4,2                        35
#  4,3                        35
#  2,5                        35
#  5,1                        35
#  850.0                      35
#  268                        35
#  365.0                      35
#  221.0                      34
#  223.0                      34
#  246.0                      34
#  285.0                      34
#  940                        33
#  263                        33
#  345                        32
#  277                        32
#  256.0                      32
#  870                        32
#  267                        32
#  219.0                      31
#  335                        31
#  242.0                      31
#  3,2                        30
#  8,5                        30
#  4,4                        30
#  430.0                      30
#  7,8                        30
#  770.0                      30
#  5.20000000000000018        30
#  10,3                       30
#  325.0                      30
#  11,5                       30
#  264                        29
#  262                        29
#  385                        29
#  236.0                      29
#  525.0                      28
#  252.0                      28
#  248.0                      27
#  880.0                      27
#  273                        27
#  5.40000000000000036        27
#  251                        27
#  312.0                      27
#  237.0                      26
#  238.0                      26
#  970.0                      26
#  890                        25
#  4,9                        25
#  950.0                      25
#  2.0                        25
#  271                        25
#  930.0                      25
#  7,7                        25
#  860.0                      25
#  830.0                      24
#  375                        24
#  5.79999999999999982        24
#  5.59999999999999964        24
#  1                          24
#  243                        24
#  513.0                      24
#  232.0                      24
#  990.0                      24
#  960.0                      24
#  274                        24
#  266                        23
#  470                        23
#  258                        23
#  231.0                      22
#  276.0                      22
#  440.0                      22
#  229.0                      22
#  840.0                      22
#  278                        22
#  239                        22
#  254.0                      21
#  355                        21
#  294.0                      21
#  405                        21
#  425                        21
#  291                        21
#  227.0                      21
#  282                        21
#  395.0                      20
#  5.2                        20
#  4,6                        20
#  283                        20
#  7,1                        20
#  3,3                        20
#  10,8                       20
#  5,9                        20
#  247.0                      20
#  268.0                      20
#  999                        20
#  535                        20
#  253                        20
#  3,9                        20
#  795                        20
#  233.0                      20
#  288                        20
#  10.5                       20
#  490                        19
#  790.0                      19
#  925                        19
#  244                        18
#  605                        18
#  5.4                        18
#  267.0                      18
#  273.0                      18
#  259                        18
#  287                        18
#  249                        18
#  277.0                      18
#  870.0                      18
#  281                        18
#  940.0                      17
#  257.0                      17
#  263.0                      17
#  625                        17
#  318                        17
#  5.6                        16
#  274.0                      16
#  243.0                      16
#  241                        16
#  264.0                      16
#  261                        16
#  460.0                      16
#  385.0                      16
#  5.8                        16
#  269                        15
#  272.0                      15
#  16                         15
#  3,4                        15
#  5.09999999999999964        15
#  5.70000000000000018        15
#  685                        15
#  4.59999999999999964        15
#  8,1                        15
#  7,4                        15
#  435                        15
#  890.0                      15
#  6.40000000000000036        15
#  8,8                        15
#  14,5                       15
#  4.20000000000000018        15
#  575                        15
#  6,1                        15
#  635                        14
#  364                        14
#  313                        14
#  335.0                      14
#  282.0                      14
#  425.0                      14
#  405.0                      14
#  980                        13
#  485                        13
#  345.0                      13
#  735                        13
#  384                        13
#  308                        13
#  314                        13
#  675                        13
#  278.0                      13
#  251.0                      13
#  602                        13
#  244.0                      12
#  266.0                      12
#  286                        12
#  545                        12
#  4.79999999999999982        12
#  323                        12
#  455                        12
#  825                        12
#  470.0                      12
#  258.0                      12
#  712                        12
#  281.0                      12
#  6.20000000000000018        12
#  605.0                      12
#  555                        12
#  292                        11
#  645                        11
#  262.0                      11
#  375.0                      11
#  925.0                      11
#  490.0                      11
#  348                        11
#  304                        11
#  6.5                        10
#  298                        10
#  4.6                        10
#  4.2                        10
#  4,1                        10
#  655                        10
#  8,2                        10
#  269.0                      10
#  9,2                        10
#  6.4                        10
#  435.0                      10
#  271.0                      10
#  5.7                        10
#  413                        10
#  3,7                        10
#  6,9                        10
#  535.0                      10
#  402                        10
#  795.0                      10
#  575.0                      10
#  9,5                        10
#  5.1                        10
#  12,5                       10
#  2,6                        10
#  2,4                        10
#  6,15                       10
#  999.0                      10
#  288.0                      10
#  10,4                       10
#  253.0                      10
#  2,9                        10
#  9,3                        10
#  2                          10
#  745                        10
#  585                         9
#  293                         9
#  5.29999999999999982         9
#  725                         9
#  351                         9
#  514                         9
#  361                         9
#  2.89999999999999991         9
#  241.0                       9
#  465                         9
#  352                         9
#  261.0                       9
#  895                         9
#  813                         9
#  19                          9
#  6.29999999999999982         9
#  705                         9
#  324                         9
#  296                         9
#  6.70000000000000018         9
#  4.40000000000000036         9
#  511                         9
#  412                         9
#  355.0                       9
#  306                         9
#  317                         9
#  595                         9
#  284                         9
#  291.0                       9
#  332                         9
#  323.0                       8
#  545.0                       8
#  307                         8
#  4.8                         8
#  712.0                       8
#  239.0                       8
#  279                         8
#  555.0                       8
#  785                         8
#  318.0                       8
#  825.0                       8
#  625.0                       8
#  6.2                         8
#  384.0                       7
#  735.0                       7
#  675.0                       7
#  287.0                       7
#  314.0                       7
#  602.0                       7
#  980.0                       7
#  297                         7
#  259.0                       7
#  485.0                       7
#  308.0                       7
#  445                         7
#  945                         7
#  249.0                       7
#  309                         7
#  885                         7
#  321                         7
#  657                         7
#  7.59999999999999964         6
#  6.7                         6
#  512                         6
#  465.0                       6
#  6.3                         6
#  622                         6
#  289                         6
#  347                         6
#  3.60000000000000009         6
#  522                         6
#  595.0                       6
#  361.0                       6
#  362                         6
#  313.0                       6
#  514.0                       6
#  4.90000000000000036         6
#  374                         6
#  423                         6
#  516                         6
#  386                         6
#  353                         6
#  412.0                       6
#  351.0                       6
#  302                         6
#  775                         6
#  372                         6
#  5.90000000000000036         6
#  585.0                       6
#  527                         6
#  895.0                       6
#  352.0                       6
#  635.0                       6
#  2.39999999999999991         6
#  565                         6
#  683                         6
#  296.0                       6
#  366                         6
#  411                         6
#  327                         6
#  813.0                       6
#  875                         6
#  705.0                       6
#  855                         6
#  324.0                       6
#  332.0                       6
#  284.0                       6
#  5.3                         6
#  2.9                         6
#  725.0                       6
#  293.0                       6
#  623                         6
#  733                         6
#  306.0                       6
#  364.0                       6
#  317.0                       6
#  4.4                         6
#  322                         6
#  371                         6
#  511.0                       6
#  475                         6
#  508                         6
#  338                         5
#  2,8                         5
#  10,7                        5
#  658                         5
#  12,7                        5
#  3,1                         5
#  10,35                       5
#  389                         5
#  608                         5
#  6,85                        5
#  13,8                        5
#  19,5                        5
#  13.5                        5
#  5,79                        5
#  11,3                        5
#  6.25                        5
#  4,61                        5
#  7,76                        5
#  6,84                        5
#  3.5                         5
#  298.0                       5
#  11,1                        5
#  9,4                         5
#  402.0                       5
#  9,1                         5
#  13,3                        5
#  8,7                         5
#  413.0                       5
#  1,4                         5
#  4,35                        5
#  5,75                        5
#  10,25                       5
#  8,3                         5
#  745.0                       5
#  8,4                         5
#  7,15                        5
#  11,6                        5
#  3,75                        5
#  7,45                        5
#  11,4                        5
#  283.0                       5
#  5,25                        5
#  685.0                       5
#  12,4                        5
#  10,2                        5
#  4,15                        5
#  655.0                       5
#  4,75                        5
#  5,15                        5
#  392                         4
#  4.9                         4
#  5.9                         4
#  704                         4
#  342                         4
#  7.599999999999999           4
#  403                         4
#  326                         4
#  3.6                         4
#  961                         4
#  838                         4
#  2.4                         4
#  303                         4
#  995                         4
#  516.0                       4
#  522.0                       4
#  733.0                       4
#  565.0                       4
#  366.0                       4
#  371.0                       4
#  527.0                       4
#  347.0                       4
#  289.0                       4
#  372.0                       4
#  775.0                       4
#  875.0                       4
#  292.0                       4
#  327.0                       4
#  475.0                       4
#  304.0                       4
#  362.0                       4
#  411.0                       4
#  423.0                       4
#  322.0                       4
#  512.0                       4
#  302.0                       4
#  622.0                       4
#  348.0                       4
#  683.0                       4
#  645.0                       4
#  508.0                       4
#  855.0                       4
#  623.0                       4
#  353.0                       4
#  386.0                       4
#  374.0                       4
#  8.59999999999999964         3
#  391                         3
#  456                         3
#  845                         3
#  806                         3
#  428                         3
#  802                         3
#  452                         3
#  564                         3
#  478                         3
#  492                         3
#  363                         3
#  431                         3
#  765                         3
#  396                         3
#  427                         3
#  789                         3
#  547                         3
#  316                         3
#  417                         3
#  714                         3
#  874                         3
#  333                         3
#  8.80000000000000071         3
#  814                         3
#  505                         3
#  601                         3
#  4.29999999999999982         3
#  4.45000000000000018         3
#  6.59999999999999964         3
#  909                         3
#  3.39999999999999991         3
#  404                         3
#  872                         3
#  574                         3
#  526                         3
#  713                         3
#  695                         3
#  442                         3
#  -81                         3
#  781                         3
#  644                         3
#  935                         3
#  379                         3
#  665                         3
#  328                         3
#  376                         3
#  486                         3
#  707                         3
#  588                         3
#  563                         3
#  393                         3
#  965                         3
#  607                         3
#  774                         3
#  488                         3
#  334                         3
#  468                         3
#  369                         3
#  523                         3
#  614                         3
#  509                         3
#  3.10000000000000009         3
#  13.8499999999999996         3
#  2.79999999999999982         3
#  311                         3
#  866                         3
#  916                         3
#  421                         3
#  4.09999999999999964         3
#  985                         3
#  373                         3
#  496                         3
#  701                         3
#  382                         3
#  609                         3
#  383                         3
#  346                         3
#  755                         3
#  409                         3
#  4.70000000000000018         3
#  616                         3
#  805                         3
#  766                         3
#  532                         3
#  3.79999999999999982         3
#  454                         3
#  562                         3
#  6.04999999999999982         3
#  657.0                       3
#  885.0                       3
#  286.0                       3
#  455.0                       3
#  445.0                       3
#  945.0                       3
#  297.0                       3
#  309.0                       3
#  321.0                       3
#  765.0                       2
#  789.0                       2
#  396.0                       2
#  363.0                       2
#  478.0                       2
#  564.0                       2
#  427.0                       2
#  802.0                       2
#  333.0                       2
#  845.0                       2
#  547.0                       2
#  316.0                       2
#  379.0                       2
#  874.0                       2
#  328.0                       2
#  665.0                       2
#  985.0                       2
#  373.0                       2
#  428.0                       2
#  417.0                       2
#  456.0                       2
#  909.0                       2
#  486.0                       2
#  279.0                       2
#  311.0                       2
#  334.0                       2
#  707.0                       2
#  393.0                       2
#  965.0                       2
#  607.0                       2
#  774.0                       2
#  376.0                       2
#  404.0                       2
#  8.8                         2
#  574.0                       2
#  695.0                       2
#  442.0                       2
#  -81.0                       2
#  781.0                       2
#  644.0                       2
#  935.0                       2
#  872.0                       2
#  307.0                       2
#  492.0                       2
#  601.0                       2
#  6.05                        2
#  496.0                       2
#  454.0                       2
#  2.8                         2
#  701.0                       2
#  3.1                         2
#  614.0                       2
#  509.0                       2
#  916.0                       2
#  563.0                       2
#  488.0                       2
#  588.0                       2
#  421.0                       2
#  8.599999999999998           2
#  431.0                       2
#  391.0                       2
#  452.0                       2
#  806.0                       2
#  714.0                       2
#  713.0                       2
#  526.0                       2
#  814.0                       2
#  505.0                       2
#  523.0                       2
#  13.85                       2
#  785.0                       2
#  562.0                       2
#  382.0                       2
#  609.0                       2
#  4.3                         2
#  383.0                       2
#  4.45                        2
#  6.6                         2
#  369.0                       2
#  346.0                       2
#  409.0                       2
#  3.4                         2
#  616.0                       2
#  866.0                       2
#  468.0                       2
#  805.0                       2
#  4.7                         2
#  3.8                         2
#  4.1                         2
#  755.0                       2
#  532.0                       2
#  766.0                       2
#  392.0                       1
#  303.0                       1
#  995.0                       1
#  838.0                       1
#  961.0                       1
#  326.0                       1
#  704.0                       1
#  342.0                       1
#  403.0                       1
#  Name: larrout, dtype: int64,
#  564205)

# %%
lieux_df['surf'] = lieux_df['surf'].fillna(1, inplace=False)

# Conversion des valeurs de type '2.0' en '2' tout en restant en str
lieux_df['surf'] = lieux_df['surf'].astype(str)
lieux_df['surf'] = lieux_df['surf'].apply(lambda x: str(int(float(x))) if x.replace('.', '', 1).lstrip('-').isdigit() and '.' in x else x)

# Remplacer '02' par '2', et espaces devant chiffres
lieux_df['surf'] = lieux_df['surf'].apply(lambda x: str(int(x.strip())) if x.strip().replace('-', '').isdigit() else x)

lieux_df['surf'] = pd.to_numeric(lieux_df['surf'], errors='coerce')
lieux_df['surf'] = lieux_df['surf'].replace({-1: 1,0: 1, 9: 1})
# on remplace les valeurs nulles (65k) par la plus fréquente

# %%
lieux_df['surf'].value_counts()
# Out:
# 1    4794010
# 2    1010755
# 7      34740
# 5      16425
# 8      13675
# 3       8355
# 6       3505
# 4       2900
# Name: surf, dtype: int64

# %%
lieux_df['infra'].value_counts(), lieux_df['infra'].isna().sum()
# Out:
# (0       3096267
#  0.0     2064178
#  5        205572
#  5.0      137048
#  3         53304
#  2         51849
#  3.0       35536
#  2.0       34566
#  1         32262
#  6         24987
#  9         24111
#  1.0       21508
#  6.0       16658
#  9.0       16074
#  4         12339
#  4.0        8226
#   -1        6708
#  8          4899
#  -1.0       4472
#  8.0        3266
#  7          2097
#  7.0        1398
#  Name: infra, dtype: int64,
#  27040)

# %%
lieux_df['infra'] = lieux_df['infra'].fillna(1, inplace=False)

# Conversion des valeurs de type '2.0' en '2' tout en restant en str
lieux_df['infra'] = lieux_df['infra'].astype(str)
lieux_df['infra'] = lieux_df['infra'].apply(lambda x: str(int(float(x))) if x.replace('.', '', 1).lstrip('-').isdigit() and '.' in x else x)

# Remplacer '02' par '2', et espaces devant chiffres
lieux_df['infra'] = lieux_df['infra'].apply(lambda x: str(int(x.strip())) if x.strip().replace('-', '').isdigit() else x)

lieux_df['infra'] = pd.to_numeric(lieux_df['infra'], errors='coerce')
lieux_df['infra'] = lieux_df['infra'].replace({-1: 1})
# on remplace les valeurs nulles par la plus fréquente,
# 0 ne l'étant pas car ça veut dire qu'il n'y a pas d'infra,
# 9 peut être pertinent car c'est une infra 'autre'

# %%
lieux_df['infra'].value_counts()
# Out:
# 0    5160445
# 5     342620
# 1      91990
# 3      88840
# 2      86415
# 6      41645
# 9      40185
# 4      20565
# 8       8165
# 7       3495
# Name: infra, dtype: int64

# %%
lieux_df['situ'].value_counts(), lieux_df['situ'].isna().sum()
# Out:
# (1       2949954
#  1.0     1966636
#  3        276807
#  3.0      184538
#  0        142374
#  0.0       94916
#  4         62058
#  4.0       41372
#  5         31272
#  2         25368
#  5.0       20848
#  8         19710
#  2.0       16912
#  8.0       13140
#  6          7740
#  6.0        5160
#   -1         426
#  -1.0        284
#  Name: situ, dtype: int64,
#  24850)

# %%
lieux_df['situ'] = lieux_df['situ'].fillna(1, inplace=False)

# Conversion des valeurs de type '2.0' en '2' tout en restant en str
lieux_df['situ'] = lieux_df['situ'].astype(str)
lieux_df['situ'] = lieux_df['situ'].apply(lambda x: str(int(float(x))) if x.replace('.', '', 1).lstrip('-').isdigit() and '.' in x else x)

# Remplacer '02' par '2', et espaces devant chiffres
lieux_df['situ'] = lieux_df['situ'].apply(lambda x: str(int(x.strip())) if x.strip().replace('-', '').isdigit() else x)

lieux_df['situ'] = pd.to_numeric(lieux_df['situ'], errors='coerce')
lieux_df['situ'] = lieux_df['situ'].replace({-1: 1, 0: 1})
# on remplace les valeurs nulles par la plus fréquentes

# %%
lieux_df['situ'].value_counts()
# Out:
# 1    5179440
# 3     461345
# 4     103430
# 5      52120
# 2      42280
# 8      32850
# 6      12900
# Name: situ, dtype: int64

# %%
lieux_df['catr'].value_counts(), lieux_df['catr'].isna().sum()
# Out:
# (4      1715616
#  3      1157427
#  4.0    1143744
#  3.0     771618
#  1       279267
#  2       269340
#  1.0     186178
#  2.0     179560
#  9        56964
#  9.0      37976
#  6        23946
#  7        21825
#  6.0      15964
#  7.0      14550
#  5         6231
#  5.0       4154
#  Name: catr, dtype: int64,
#  5)

# %%
lieux_df['catr'] = lieux_df['catr'].fillna(4, inplace=False)

# Conversion des valeurs de type '2.0' en '2' tout en restant en str
lieux_df['catr'] = lieux_df['catr'].astype(str)
lieux_df['catr'] = lieux_df['catr'].apply(lambda x: str(int(float(x))) if x.replace('.', '', 1).lstrip('-').isdigit() and '.' in x else x)

# Remplacer '02' par '2', et espaces devant chiffres
lieux_df['catr'] = lieux_df['catr'].apply(lambda x: str(int(x.strip())) if x.strip().replace('-', '').isdigit() else x)

# %%
lieux_df['catr'].value_counts()
# Out:
# 4    2859365
# 3    1929045
# 1     465445
# 2     448900
# 9      94940
# 6      39910
# 7      36375
# 5      10385
# Name: catr, dtype: int64

# %% [markdown]
# Drop des col

# %%
lieux_df_clean = lieux_df.drop(columns=['voie', 'v1', 'v2', 'pr', 'pr1', 'lartpc', 'larrout', 'vma', 'env1'])

# %%
lieux_df_clean.head(2)
# Out:
#         Num_Acc catr  circ  nbv  vosp  prof  plan  surf  infra  situ
# 0  201700000001    3     2    2     2     1     1     1      0     1
# 1  201700000002    3     2    2     0     1     1     1      1     1

# %% [markdown]
# Export .csv

# %%
lieux_df_clean.to_csv('../clean_data/lieux_clean.csv', index=False)

# %% [markdown]
# ## Dataset usagers

# %%
usager_df.head(2)
# Out:
#         Num_Acc place catu grav sexe trajet secu locp actp etatp an_nais  \
# 0  200600000001     1    1    4    1      5   11    0    0     0    1949
# 1  200600000001     2    2    4    2      0   11    0    0     0    1948
#
#   num_veh id_vehicule secu1 secu2 secu3 id_usager
# 0     B01         NaN   NaN   NaN   NaN       NaN
# 1     B01         NaN   NaN   NaN   NaN       NaN

# %% [markdown]
# Cleaning

# %%
usager_df['grav'].value_counts(), usager_df['grav'].isna().sum()
# Out:
# (1      5413730
#  4      4809425
#  3      2604085
#  2       353140
#   -1        903
#  -1         602
#  Name: grav, dtype: int64,
#  0)

# %%
usager_df['grav'] = usager_df['grav'].apply(lambda x: str(int(x.strip())) if x.strip().replace('-', '').isdigit() else x)
# Remplacer '02' par '2', et espaces devant chiffres

usager_df['grav'] = pd.to_numeric(usager_df['grav'], errors='coerce')
usager_df['grav'] = usager_df['grav'].replace({-1: 1})
# on remplace les valeurs nulle par la plus fréquente

# %%
usager_df['grav'].value_counts()
# Out:
# 1    5415235
# 4    4809425
# 3    2604085
# 2     353140
# Name: grav, dtype: int64

# %%
usager_df['sexe'].value_counts(), usager_df['sexe'].isna().sum()
# Out:
# (1      8865950
#  2      4286905
#   -1      17418
#  -1       11612
#  Name: sexe, dtype: int64,
#  0)

# %%
usager_df['sexe'] = usager_df['sexe'].apply(lambda x: str(int(x.strip())) if x.strip().replace('-', '').isdigit() else x)
# Remplacer '02' par '2', et espaces devant chiffres

usager_df['sexe'] = pd.to_numeric(usager_df['sexe'], errors='coerce')
usager_df['sexe'] = usager_df['sexe'].replace({-1: 1})
# on remplace les valeurs nulle par la plus fréquente

# %%
usager_df['sexe'].value_counts()
# Out:
# 1    8894980
# 2    4286905
# Name: sexe, dtype: int64

# %%
usager_df['trajet'].value_counts(), usager_df['trajet'].isna().sum()
# Out:
# (5       2935245
#  0       2204202
#  5.0     1956830
#  0.0     1469468
#  1       1034712
#  4        767256
#  1.0      689808
#  9        568125
#  4.0      511504
#  9.0      378750
#  3        213120
#  2        164289
#  3.0      142080
#  2.0      109526
#   -1       20700
#  -1.0      13800
#  Name: trajet, dtype: int64,
#  2470)

# %%
usager_df['trajet'] = usager_df['trajet'].fillna(5, inplace=False)

# Conversion des valeurs de type '2.0' en '2' tout en restant en str
usager_df['trajet'] = usager_df['trajet'].astype(str)
usager_df['trajet'] = usager_df['trajet'].apply(lambda x: str(int(float(x))) if x.replace('.', '', 1).lstrip('-').isdigit() and '.' in x else x)

# Remplacer '02' par '2', et espaces devant chiffres
usager_df['trajet'] = usager_df['trajet'].apply(lambda x: str(int(x.strip())) if x.strip().replace('-', '').isdigit() else x)

usager_df['trajet'] = pd.to_numeric(usager_df['trajet'], errors='coerce')
usager_df['trajet'] = usager_df['trajet'].replace({-1: 5})
# Remplacez les valeurs -1 par 5

# %%
usager_df['trajet'] = usager_df['trajet'].astype(int)

values_destribution_trajet = usager_df['trajet'][usager_df['trajet'] > 0].value_counts(normalize=True)
new_values_manv = np.random.choice(values_destribution_trajet.index, size = (usager_df['trajet'] == 0).sum(), p=values_destribution_trajet.values)
usager_df.loc[usager_df['trajet'] == 0, 'trajet'] = new_values_manv
#Remplacer les 0 par la distrib

# %%
usager_df['trajet'].value_counts()
# Out:
# 5    6833702
# 1    2391418
# 4    1772901
# 9    1312371
# 3     492075
# 2     379418
# Name: trajet, dtype: int64

# %%
usager_df['secu'].value_counts(), usager_df['secu'].isna().sum()
# Out:
# (11      3592401
#  11.0    2394934
#  21      1168512
#  21.0     779008
#  13       500739
#  13.0     333826
#  93       315363
#  93.0     210242
#  00       205122
#  0.0      136748
#  23       122595
#  12       108945
#  23.0      81730
#  12.0      72630
#  22        67122
#  31        44928
#  22.0      44748
#  31.0      29952
#  3         23121
#  92        23079
#  91        22959
#  10        16893
#  3.0       15414
#  92.0      15386
#  91.0      15306
#  10.0      11262
#  1         10701
#  2          8007
#  41         7596
#  1.0        7136
#  43         6012
#  42         5568
#  2.0        5338
#  41.0       5064
#  43.0       4008
#  42.0       3712
#  33         2511
#  32         2283
#  20         2262
#  33.0       1674
#  32.0       1522
#  20.0       1508
#  90          219
#  90.0        146
#  30           27
#  30.0         18
#  40            6
#  40.0          4
#  01            3
#  Name: secu, dtype: int64,
#  2753595)

# %%
usager_df['secu'] = usager_df['secu'].fillna(usager_df['secu1'])
#on remplace les valeurs nulles par les valeurs nulles de secu (avant 2019) par les valeurs de secu1(après 2019)

# %%
usager_df['secu'] = usager_df['secu'].fillna(11, inplace=False)

# %%
# Conversion des valeurs de type '2.0' en '2' tout en restant en str
usager_df['secu'] = usager_df['secu'].astype(str)
usager_df['secu'] = usager_df['secu'].apply(lambda x: str(int(float(x))) if x.replace('.', '', 1).lstrip('-').isdigit() and '.' in x else x)

# Remplacer '02' par '2', et espaces devant chiffres
usager_df['secu'] = usager_df['secu'].apply(lambda x: str(int(x.strip())) if x.strip().replace('-', '').isdigit() else x)

# %%
usager_df['secu'] = pd.to_numeric(usager_df['secu'], errors='coerce')
usager_df['secu'] = usager_df['secu'].apply(lambda x: 1 if x > 0 else 0)
# on normalise les valeurs secu (0 = Pas d'équipement, 1 = Equipement)

# %%
usager_df['secu'].value_counts()
# Out:
# 1    12606150
# 0      575735
# Name: secu, dtype: int64

# %%
usager_df['locp'].value_counts(), usager_df['locp'].isna().sum()
# Out:
# (0       6487995
#  0.0     4325330
#   -1      650259
#  -1.0     433506
#  2        151401
#  4        147990
#  3        138810
#  2.0      100934
#  4.0       98660
#  1         93897
#  3.0       92540
#  1.0       62598
#  5         42213
#  5.0       28142
#  6         14109
#  6.0        9406
#  8          7101
#  9          5532
#  8.0        4734
#  9.0        3688
#  7           741
#  7.0         494
#  Name: locp, dtype: int64,
#  281805)

# %%
usager_df['locp'] = usager_df['locp'].fillna(0, inplace=False)
# Remplacer les valeurs manquantes dans 'locp' par 0

# %%
# Conversion des valeurs de type '2.0' en '2' tout en restant en str
usager_df['locp'] = usager_df['locp'].astype(str)
usager_df['locp'] = usager_df['locp'].apply(lambda x: str(int(float(x))) if x.replace('.', '', 1).lstrip('-').isdigit() and '.' in x else x)

# Remplacer '02' par '2', et espaces devant chiffres
usager_df['locp'] = usager_df['locp'].apply(lambda x: str(int(x.strip())) if x.strip().replace('-', '').isdigit() else x)

# %%
# Remplacer les valeurs -1 par 0 dans 'locp'
usager_df['locp'] = pd.to_numeric(usager_df['locp'], errors='coerce')
usager_df['locp'] = usager_df['locp'].replace({-1: 0})

# %%
usager_df['locp'].value_counts(), usager_df['locp'].isna().sum()
# Out:
# (0    12178895
#  2      252335
#  4      246650
#  3      231350
#  1      156495
#  5       70355
#  6       23515
#  8       11835
#  9        9220
#  7        1235
#  Name: locp, dtype: int64,
#  0)

# %%
usager_df['actp'].value_counts(), usager_df['actp'].isna().sum()
# On drop cette colonne, la répertition est trop compliquée
# Out:
# (0      7382879
#  0.0    3536496
#   -1     928330
#  3       552184
#  3.0     244811
#  9        51046
#  1        42992
#  5        40465
#  9.0      22709
#  2        21083
#  5.0      19200
#  1.0      18148
#  4        12867
#  2.0       8987
#  B         6170
#  4.0       5968
#  A         2110
#  6         1811
#  6.0        759
#  7          300
#  8          260
#  Name: actp, dtype: int64,
#  282310)

# %%
usager_df['etatp'].value_counts(), usager_df['etatp'].isna().sum()
# Out:
# (0       5744379
#  0.0     3829586
#   -1     1368738
#  -1.0     912492
#  1        475443
#  1.0      316962
#  2        124527
#  2.0       83018
#  3         26790
#  3.0       17860
#  Name: etatp, dtype: int64,
#  282090)

# %%
usager_df['etatp'] = usager_df['etatp'].fillna(0, inplace=False)

# %%
# Conversion des valeurs de type '2.0' en '2' tout en restant en str
usager_df['etatp'] = usager_df['etatp'].astype(str)
usager_df['etatp'] = usager_df['etatp'].apply(lambda x: str(int(float(x))) if x.replace('.', '', 1).lstrip('-').isdigit() and '.' in x else x)

# Remplacer '02' par '2', et espaces devant chiffres
usager_df['etatp'] = usager_df['etatp'].apply(lambda x: str(int(x.strip())) if x.strip().replace('-', '').isdigit() else x)

# %%
usager_df['etatp'].value_counts()
# On drop la colonne, trop de -1 et trop de 0 qui correspondent à l'absence de valeur
# Out:
# 0     9856055
# -1    2281230
# 1      792405
# 2      207545
# 3       44650
# Name: etatp, dtype: int64

# %%
usager_df['an_nais'].value_counts(), usager_df['an_nais'].isna().sum()
# Out:
# (1988      198846
#  1987      198723
#  1986      198591
#  1989      193491
#  1985      192525
#  1990      188949
#  1984      180072
#  1982      172533
#  1991      172431
#  1983      170316
#  1980      166017
#  1981      165537
#  1992      159888
#  1979      145554
#  1993      142491
#  1978      139749
#  1972      138459
#  1977      138036
#  1973      137988
#  1971      135276
#  1974      134235
#  1994      133440
#  1988.0    132564
#  1987.0    132482
#  1986.0    132394
#  1975      132246
#  1976      131139
#  1970      129951
#  1989.0    128994
#  1985.0    128350
#  1995      126249
#  1990.0    125966
#  1969      124311
#  1968      121962
#  1966      120726
#  1984.0    120048
#  1967      119730
#  1965      119124
#  1964      118293
#  1963      115371
#  1996      115326
#  1982.0    115022
#  1991.0    114954
#  1983.0    113544
#  1980.0    110678
#  1981.0    110358
#  1962      108621
#  1961      107103
#  1992.0    106592
#  1997      106218
#  1960      103704
#  1998       99033
#  1959       98688
#  1979.0     97036
#  1993.0     94994
#  1978.0     93166
#  1972.0     92306
#  1958       92103
#  1977.0     92024
#  1973.0     91992
#  1999       91479
#  1971.0     90184
#  1974.0     89490
#  1957       89202
#  1994.0     88960
#  1975.0     88164
#  2000       88032
#  1976.0     87426
#  1970.0     86634
#  1956       84642
#  1995.0     84166
#  1969.0     82874
#  1955       81498
#  1968.0     81308
#  1966.0     80484
#  1967.0     79820
#  1965.0     79416
#  1964.0     78862
#  1954       77619
#  1963.0     76914
#  1996.0     76884
#  2001       75483
#  1962.0     72414
#  1953       72285
#  1961.0     71402
#  1997.0     70812
#  1952       70587
#  1960.0     69136
#  1950       67266
#  1998.0     66022
#  1959.0     65792
#  1951       65781
#  2002       63657
#  1949       61443
#  1958.0     61402
#  1999.0     60986
#  1957.0     59468
#  1948       59067
#  2000.0     58688
#  1947       56685
#  1956.0     56428
#  1955.0     54332
#  1946       52419
#  2003       52362
#  1954.0     51746
#  2001.0     50322
#  1953.0     48190
#  1952.0     47058
#  1950.0     44844
#  1951.0     43854
#  2004       42549
#  2002.0     42438
#  1945       41427
#  1949.0     40962
#  1944       39480
#  1948.0     39378
#  1943       38436
#  1947.0     37790
#  2005       35844
#  1946.0     34946
#  2003.0     34908
#  1942       34344
#  2006       30411
#  1941       30279
#  1940       30267
#  1938       29877
#  1939       29757
#  1937       28758
#  1936       28515
#  2004.0     28366
#  1945.0     27618
#  1935       27228
#  1934       26967
#  1944.0     26320
#  1943.0     25624
#  1933       25197
#  1932       24999
#  2007       24345
#  2005.0     23896
#  1931       23352
#  1942.0     22896
#  1930       22122
#  2008       20769
#  2006.0     20274
#  1941.0     20186
#  1940.0     20178
#  1938.0     19918
#  1939.0     19838
#  1929       19254
#  1937.0     19172
#  1936.0     19010
#  2009       18411
#  1935.0     18152
#  1934.0     17978
#  1928       17799
#  1933.0     16798
#  1932.0     16666
#  2010       16662
#  2007.0     16230
#  1927       15657
#  1931.0     15568
#  1930.0     14748
#  2011       14247
#  1926       13980
#  2008.0     13846
#  1929.0     12836
#  2012       12489
#  2009.0     12274
#  1925       12249
#  1928.0     11866
#  2010.0     11108
#  2013       11046
#  1924       10473
#  1927.0     10438
#  2014        9927
#  2011.0      9498
#  1926.0      9320
#  1923        9129
#  2015        8565
#  2012.0      8326
#  1925.0      8166
#  1922        7566
#  2013.0      7364
#  2016        7140
#  1924.0      6982
#  1921        6648
#  2014.0      6618
#  1923.0      6086
#  2017        5910
#  2015.0      5710
#  1920        5472
#  1922.0      5044
#  2018        4920
#  2016.0      4760
#  1921.0      4432
#  2017.0      3940
#  1920.0      3648
#  2019        3537
#  2018.0      3280
#  1919        2853
#  2019.0      2358
#  2020        2274
#  1919.0      1902
#  1918        1719
#  2021        1575
#  2020.0      1516
#  1917        1263
#  1918.0      1146
#  2021.0      1050
#  1900         858
#  1914         855
#  1917.0       842
#  1916         831
#  1915         714
#  2022         594
#  1900.0       572
#  1914.0       570
#  1916.0       554
#  1913         540
#  1915.0       476
#  2022.0       396
#  1912         366
#  1913.0       360
#  1911         252
#  1912.0       244
#  1901         240
#  1910         225
#  1911.0       168
#  1901.0       160
#  1910.0       150
#  1898         105
#  1909          96
#  1898.0        70
#  1909.0        64
#  1908          39
#  1908.0        26
#  1906          24
#  1907          24
#  1907.0        16
#  1906.0        16
#  1905          15
#  1905.0        10
#  1903           9
#  1897           9
#  1899           6
#  1902           6
#  1903.0         6
#  1897.0         6
#  1899.0         4
#  1902.0         4
#  1904           3
#  1896           3
#  1896.0         2
#  1904.0         2
#  Name: an_nais, dtype: int64,
#  41795)

# %%
# Drop les lignes avec des valeurs manquantes dans 'an_nais'
usager_df = usager_df.dropna(subset=['an_nais'], inplace=False)

# %%
# Conversion des valeurs de type '2.0' en '2' tout en restant en str
usager_df['an_nais'] = usager_df['an_nais'].astype(str)
usager_df['an_nais'] = usager_df['an_nais'].apply(lambda x: str(int(float(x))) if x.replace('.', '', 1).lstrip('-').isdigit() and '.' in x else x)

# Remplacer '02' par '2', et espaces devant chiffres
usager_df['an_nais'] = usager_df['an_nais'].apply(lambda x: str(int(x.strip())) if x.strip().replace('-', '').isdigit() else x)

# %%
print(usager_df[~usager_df['an_nais'].str.match(r'^\d{4}$')])
# Checking des valeur différentes de 'YYYY'
# Out:
# Empty DataFrame
# Columns: [Num_Acc, place, catu, grav, sexe, trajet, secu, locp, actp, etatp, an_nais, num_veh, id_vehicule, secu1, secu2, secu3, id_usager]
# Index: []

# %%
usager_df['an_nais'].value_counts()
# Out:
# 1988    331410
# 1987    331205
# 1986    330985
# 1989    322485
# 1985    320875
# 1990    314915
# 1984    300120
# 1982    287555
# 1991    287385
# 1983    283860
# 1980    276695
# 1981    275895
# 1992    266480
# 1979    242590
# 1993    237485
# 1978    232915
# 1972    230765
# 1977    230060
# 1973    229980
# 1971    225460
# 1974    223725
# 1994    222400
# 1975    220410
# 1976    218565
# 1970    216585
# 1995    210415
# 1969    207185
# 1968    203270
# 1966    201210
# 1967    199550
# 1965    198540
# 1964    197155
# 1963    192285
# 1996    192210
# 1962    181035
# 1961    178505
# 1997    177030
# 1960    172840
# 1998    165055
# 1959    164480
# 1958    153505
# 1999    152465
# 1957    148670
# 2000    146720
# 1956    141070
# 1955    135830
# 1954    129365
# 2001    125805
# 1953    120475
# 1952    117645
# 1950    112110
# 1951    109635
# 2002    106095
# 1949    102405
# 1948     98445
# 1947     94475
# 1946     87365
# 2003     87270
# 2004     70915
# 1945     69045
# 1944     65800
# 1943     64060
# 2005     59740
# 1942     57240
# 2006     50685
# 1941     50465
# 1940     50445
# 1938     49795
# 1939     49595
# 1937     47930
# 1936     47525
# 1935     45380
# 1934     44945
# 1933     41995
# 1932     41665
# 2007     40575
# 1931     38920
# 1930     36870
# 2008     34615
# 1929     32090
# 2009     30685
# 1928     29665
# 2010     27770
# 1927     26095
# 2011     23745
# 1926     23300
# 2012     20815
# 1925     20415
# 2013     18410
# 1924     17455
# 2014     16545
# 1923     15215
# 2015     14275
# 1922     12610
# 2016     11900
# 1921     11080
# 2017      9850
# 1920      9120
# 2018      8200
# 2019      5895
# 1919      4755
# 2020      3790
# 1918      2865
# 2021      2625
# 1917      2105
# 1900      1430
# 1914      1425
# 1916      1385
# 1915      1190
# 2022       990
# 1913       900
# 1912       610
# 1911       420
# 1901       400
# 1910       375
# 1898       175
# 1909       160
# 1908        65
# 1907        40
# 1906        40
# 1905        25
# 1897        15
# 1903        15
# 1902        10
# 1899        10
# 1904         5
# 1896         5
# Name: an_nais, dtype: int64

# %% [markdown]
# Drop de colonnes

# %%
usager_df_clean = usager_df.drop(columns=['place','catu', 'secu1','secu2','secu3','id_vehicule','id_usager', 'etatp', 'actp'])
# on drop les colonnes non pertinentes

# %%
usager_df_clean.isna().sum()
# Out:
# Num_Acc    0
# grav       0
# sexe       0
# trajet     0
# secu       0
# locp       0
# an_nais    0
# num_veh    0
# dtype: int64

# %%
usager_df_clean.head(2)
# Out:
#         Num_Acc  grav  sexe  trajet  secu  locp an_nais num_veh
# 0  200600000001     4     1       5     1     0    1949     B01
# 1  200600000001     4     2       5     1     0    1948     B01

# %% [markdown]
# Export .csv

# %%
usager_df_clean.to_csv('../clean_data/usagers_clean.csv', index=False)
# on charge le fichier nettoyé

# %% [markdown]
# ## Merging des 4 Datasets

# %%
lieux_df = pd.read_csv('../clean_data/lieux_clean.csv', dtype=str)
usagers_df = pd.read_csv('../clean_data/usagers_clean.csv', dtype=str)
vehicules_df = pd.read_csv('../clean_data/vehicules_clean.csv', dtype=str)
caracteristiques_df = pd.read_csv('../clean_data/caracteristiques_clean.csv', dtype=str)

# %%
lieux_df.head(2), lieux_df.shape
# Out:
# (        Num_Acc catr circ nbv vosp prof plan surf infra situ
#  0  201700000001    3    2   2    2    1    1    1     0    1
#  1  201700000002    3    2   2    0    1    1    1     1    1,
#  (5884365, 10))

# %%
caracteristiques_df.head(2), caracteristiques_df.shape
# Out:
# (        Num_Acc  an mois jour  hrmn lum agg int atm col  com  \
#  0  201800000001  18    1   24  1505   1   1   4   1   1  005
#  1  201800000002  18    2   12  1015   1   2   7   7   7  011
#
#                          adr      lat     long  dep
#  0    route des Ansereuilles  5055737  0294992  590
#  1  Place du général de Gaul  5052936  0293151  590  ,
#  (1121482, 15))

# %%
vehicules_df.head(2), vehicules_df.shape
# Out:
# (        Num_Acc catv obs obsm choc manv num_veh
#  0  201800000001    7   0    2    3    1     B01
#  1  201800000001    7   0    2    2   15     A01,
#  (2009395, 7))

# %%
usagers_df.head(2), usagers_df.shape
# Out:
# (        Num_Acc grav sexe trajet secu locp an_nais num_veh
#  0  200600000001    4    1      5    1    0    1949     B01
#  1  200600000001    4    2      5    1    0    1948     B01,
#  (13140090, 8))

# %%
filtered_df = vehicules_df[vehicules_df['catv'] == '1']

# %%
filtered_df.head(2), filtered_df.shape
# Out:
# (         Num_Acc catv obs obsm choc manv num_veh
#  6   201800000004    1   0    2    8    1     B01
#  30  201800000020    1  12    0    7    1     B01,
#  (88885, 7))

# %%
duplicates = filtered_df[filtered_df['Num_Acc'].duplicated(keep=False)]
print(duplicates.shape)
# Out:
# (5399, 7)

# %%
caracteristiques_df.isna().sum()
# Out:
# Num_Acc         0
# an              0
# mois            0
# jour            0
# hrmn            0
# lum             0
# agg             0
# int             0
# atm             0
# col             0
# com             0
# adr        143270
# lat        487017
# long       487021
# dep             0
# dtype: int64

# %%
a = caracteristiques_df[caracteristiques_df['Num_Acc'].isna()]
# fonction rolliwn window ? applique une fonction sur une partie précise

# %%
# Création d'une colonne uniques pour merger les df usagers et véhicules
usagers_df['aug'] = usagers_df['Num_Acc'].astype(str) + usagers_df['num_veh'].astype(str)
vehicules_df['aug'] = vehicules_df['Num_Acc'].astype(str) + vehicules_df['num_veh'].astype(str)

# %%
vehicules_df = vehicules_df[vehicules_df['catv']=='1']
# On drop les duplicates lorsqu'il y a une plusieurs usagers dans un même véhicules et pour le même accident
# On crée une colonne pour y ajouter le nombre d'usagers par véhicules

# %%
usagers_df['dup_count'] = usagers_df.groupby('aug')['aug'].transform('count')
usagers_df =usagers_df.drop_duplicates(subset=['aug'], keep='first')
print(type(vehicules_df))
print(type(usagers_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# On merge véhicules et usagers puis on ne garde que les accidents impliquant un vélo
# On clean et on drop les doublons

vehi_usa = pd.merge(vehicules_df, usagers_df, on='aug', how='inner')
vehi_usa = vehi_usa.drop(columns=['num_veh_x', 'num_veh_y', 'Num_Acc_y'])
vehi_usa = vehi_usa.rename(columns={'Num_Acc_x': 'Num_Acc'})

vehi_usa['dup_count'].value_counts()
# Out:
# 5     83223
# 10     5132
# 15      156
# 20        5
# 30        3
# 25        2
# Name: dup_count, dtype: int64

# %%
print(vehi_usa['Num_Acc'].duplicated().any())
print(caracteristiques_df['Num_Acc'].duplicated().any())
# Out:
# True
# False

# %%
duplicates_velo = vehi_usa[vehi_usa['Num_Acc'].duplicated(keep=False)]
duplicates_velo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5148 entries, 12 to 88515
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Num_Acc    5148 non-null   object
#  1   catv       5148 non-null   object
#  2   obs        5148 non-null   object
#  3   obsm       5148 non-null   object
#  4   choc       5148 non-null   object
#  5   manv       5148 non-null   object
#  6   aug        5148 non-null   object
#  7   grav       5148 non-null   object
#  8   sexe       5148 non-null   object
#  9   trajet     5148 non-null   object
#  10  secu       5148 non-null   object
#  11  locp       5148 non-null   object
#  12  an_nais    5148 non-null   object
#  13  dup_count  5148 non-null   int64
# dtypes: int64(1), object(13)
# memory usage: 603.3+ KB

# %%
# On merge les df caractéristiques et lieux
velo_df = pd.merge(vehi_usa, lieux_df, on='Num_Acc', how='left')
velo_df = pd.merge(velo_df, caracteristiques_df, on='Num_Acc', how='left')

velo_df.info()
velo_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 442605 entries, 0 to 442604
# Data columns (total 37 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Num_Acc    442605 non-null  object
#  1   catv       442605 non-null  object
#  2   obs        442605 non-null  object
#  3   obsm       442605 non-null  object
#  4   choc       442605 non-null  object
#  5   manv       442605 non-null  object
#  6   aug        442605 non-null  object
#  7   grav       442605 non-null  object
#  8   sexe       442605 non-null  object
#  9   trajet     442605 non-null  object
#  10  secu       442605 non-null  object
#  11  locp       442605 non-null  object
#  12  an_nais    442605 non-null  object
#  13  dup_count  442605 non-null  int64
#  14  catr       442605 non-null  object
#  15  circ       442605 non-null  object
#  16  nbv        442605 non-null  object
#  17  vosp       442605 non-null  object
#  18  prof       442605 non-null  object
#  19  plan       442605 non-null  object
#  20  surf       442605 non-null  object
#  21  infra      442605 non-null  object
#  22  situ       442605 non-null  object
#  23  an         416125 non-null  object
#  24  mois       416125 non-null  object
#  25  jour       416125 non-null  object
#  26  hrmn       416125 non-null  object
#  27  lum        416125 non-null  object
#  28  agg        416125 non-null  object
#  29  int        416125 non-null  object
#  30  atm        416125 non-null  object
#  31  col        416125 non-null  object
#  32  com        416125 non-null  object
#  33  adr        384870 non-null  object
#  34  lat        239580 non-null  object
#  35  long       239580 non-null  object
#  36  dep        416125 non-null  object
# dtypes: int64(1), object(36)
# memory usage: 128.3+ MB
#         Num_Acc catv obs obsm choc manv              aug grav sexe trajet  \
# 0  201800000004    1   0    2    8    1  201800000004B01    3    1      5
# 1  201800000004    1   0    2    8    1  201800000004B01    3    1      5
# 2  201800000004    1   0    2    8    1  201800000004B01    3    1      5
# 3  201800000004    1   0    2    8    1  201800000004B01    3    1      5
# 4  201800000004    1   0    2    8    1  201800000004B01    3    1      5
#
#    ... lum agg int  atm col  com                  adr      lat     long  dep
# 0  ...   1   2   1    7   3  052  30 rue Jules Guesde  5051974  0289123  590
# 1  ...   1   2   1    7   3  052  30 rue Jules Guesde  5051974  0289123  590
# 2  ...   1   2   1    7   3  052  30 rue Jules Guesde  5051974  0289123  590
# 3  ...   1   2   1    7   3  052  30 rue Jules Guesde  5051974  0289123  590
# 4  ...   1   2   1    7   3  052  30 rue Jules Guesde  5051974  0289123  590
#
# [5 rows x 37 columns]

# %%
# On remplace les valeurs manquantes par la valeur la plus fréquente
velo_df['lum'].fillna(velo_df['lum'].mode()[0], inplace=True)
velo_df['agg'].fillna(velo_df['agg'].mode()[0], inplace=True)
velo_df['atm'].fillna(velo_df['atm'].mode()[0], inplace=True)
velo_df['atm'] = velo_df['atm'].replace({ -1: 1, 9: 1})

# %%
# Obtenez la distribution des valeurs
distribution = velo_df['int'].value_counts(normalize=True)
distribution
# Out:
# 1    0.571631
# 2    0.151181
# 3    0.132809
# 6    0.073055
# 4    0.020835
# 9    0.020547
# 5    0.014395
# 7    0.014251
# 8    0.001274
# 0    0.000024
# Name: int, dtype: float64

# %%
# Obtenez les valeurs manquantes
missing = velo_df['int'].isnull()

# %%
# Remplissez les valeurs manquantes en fonction de la distribution
velo_df.loc[missing, 'int'] = np.random.choice(distribution.index, size=len(velo_df[missing]), p=distribution.values)

# %%
# Obtenez la distribution des valeurs
distribution = velo_df['col'].value_counts(normalize=True)
distribution
# Out:
# 3    0.487257
# 6    0.181039
# 1    0.118642
# 2    0.115758
# 7    0.063166
# 5    0.025497
# 4    0.008639
# Name: col, dtype: float64

# %%
# Obtenez les valeurs manquantes
missing = velo_df['col'].isnull()

# %%
# Remplissez les valeurs manquantes en fonction de la distribution
velo_df.loc[missing, 'col'] = np.random.choice(distribution.index, size=len(velo_df[missing]), p=distribution.values)

# %%
# Je remplace le -1 par 1
velo_df['col'] = velo_df['col'].replace({ -1: 3})
velo_df.info()
velo_df = velo_df[~(velo_df.adr.isna() & velo_df.lat.isna() & velo_df.long.isna() & velo_df.com.isna() & velo_df.dep.isna())]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 442605 entries, 0 to 442604
# Data columns (total 37 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Num_Acc    442605 non-null  object
#  1   catv       442605 non-null  object
#  2   obs        442605 non-null  object
#  3   obsm       442605 non-null  object
#  4   choc       442605 non-null  object
#  5   manv       442605 non-null  object
#  6   aug        442605 non-null  object
#  7   grav       442605 non-null  object
#  8   sexe       442605 non-null  object
#  9   trajet     442605 non-null  object
#  10  secu       442605 non-null  object
#  11  locp       442605 non-null  object
#  12  an_nais    442605 non-null  object
#  13  dup_count  442605 non-null  int64
#  14  catr       442605 non-null  object
#  15  circ       442605 non-null  object
#  16  nbv        442605 non-null  object
#  17  vosp       442605 non-null  object
#  18  prof       442605 non-null  object
#  19  plan       442605 non-null  object
#  20  surf       442605 non-null  object
#  21  infra      442605 non-null  object
#  22  situ       442605 non-null  object
#  23  an         416125 non-null  object
#  24  mois       416125 non-null  object
#  25  jour       416125 non-null  object
#  26  hrmn       416125 non-null  object
#  27  lum        442605 non-null  object
#  28  agg        442605 non-null  object
#  29  int        442605 non-null  object
#  30  atm        442605 non-null  object
#  31  col        442605 non-null  object
#  32  com        416125 non-null  object
#  33  adr        384870 non-null  object
#  34  lat        239580 non-null  object
#  35  long       239580 non-null  object
#  36  dep        416125 non-null  object
# dtypes: int64(1), object(36)
# memory usage: 128.3+ MB

# %%
# Réinitialisez l'index de votre DataFrame
velo_df = velo_df.reset_index(drop=True)

# %%
velo_df.columns
# Out:
# Index(['Num_Acc', 'catv', 'obs', 'obsm', 'choc', 'manv', 'aug', 'grav', 'sexe',
#        'trajet', 'secu', 'locp', 'an_nais', 'dup_count', 'catr', 'circ', 'nbv',
#        'vosp', 'prof', 'plan', 'surf', 'infra', 'situ', 'an', 'mois', 'jour',
#        'hrmn', 'lum', 'agg', 'int', 'atm', 'col', 'com', 'adr', 'lat', 'long',
#        'dep'],
#       dtype='object')

# %%
# Obtenez les valeurs manquantes
velo_df['an'].isnull().sum(), velo_df['mois'].isnull().sum(), velo_df['jour'].isnull().sum(), velo_df['hrmn'].isnull().sum()
# Out:
# (0, 0, 0, 0)

# %%
velo_df.drop(columns=['catv'], inplace=True)

# %%
velo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416125 entries, 0 to 416124
# Data columns (total 36 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Num_Acc    416125 non-null  object
#  1   obs        416125 non-null  object
#  2   obsm       416125 non-null  object
#  3   choc       416125 non-null  object
#  4   manv       416125 non-null  object
#  5   aug        416125 non-null  object
#  6   grav       416125 non-null  object
#  7   sexe       416125 non-null  object
#  8   trajet     416125 non-null  object
#  9   secu       416125 non-null  object
#  10  locp       416125 non-null  object
#  11  an_nais    416125 non-null  object
#  12  dup_count  416125 non-null  int64
#  13  catr       416125 non-null  object
#  14  circ       416125 non-null  object
#  15  nbv        416125 non-null  object
#  16  vosp       416125 non-null  object
#  17  prof       416125 non-null  object
#  18  plan       416125 non-null  object
#  19  surf       416125 non-null  object
#  20  infra      416125 non-null  object
#  21  situ       416125 non-null  object
#  22  an         416125 non-null  object
#  23  mois       416125 non-null  object
#  24  jour       416125 non-null  object
#  25  hrmn       416125 non-null  object
#  26  lum        416125 non-null  object
#  27  agg        416125 non-null  object
#  28  int        416125 non-null  object
#  29  atm        416125 non-null  object
#  30  col        416125 non-null  object
#  31  com        416125 non-null  object
#  32  adr        384870 non-null  object
#  33  lat        239580 non-null  object
#  34  long       239580 non-null  object
#  35  dep        416125 non-null  object
# dtypes: int64(1), object(35)
# memory usage: 114.3+ MB

# %%
print(velo_df['com'])
# Out:
# 0         052
# 1         052
# 2         052
# 3         052
# 4         052
#          ...
# 416120    611
# 416121    611
# 416122    611
# 416123    611
# 416124    611
# Name: com, Length: 416125, dtype: object

# %%
velo_df.head(2), velo_df.shape
# Out:
# (        Num_Acc obs obsm choc manv              aug grav sexe trajet secu  \
#  0  201800000004   0    2    8    1  201800000004B01    3    1      5    1
#  1  201800000004   0    2    8    1  201800000004B01    3    1      5    1
#
#     ... lum agg  int atm col  com                  adr      lat     long  dep
#  0  ...   1   2    1   7   3  052  30 rue Jules Guesde  5051974  0289123  590
#  1  ...   1   2    1   7   3  052  30 rue Jules Guesde  5051974  0289123  590
#
#  [2 rows x 36 columns],
#  (416125, 36))

# %% [markdown]
# Export .csv dataframe mergé

# %%
velo_df.to_csv('../clean_data/velo_df.csv', index=False)

# %% [markdown]
# ### Reconstitution lat, long pour Paris

# %% [markdown]
# ##### Call API

# %%
data = pd.read_csv('../clean_data/velo_df.csv', dtype=str)

# %%
data_filtered_paris = data.loc[data['dep'].isin(['750'])]

# %%
data_filtered_paris.head()
# Out:
#             Num_Acc obs obsm choc manv              aug grav sexe trajet secu  \
# 20235  201800050213   0    2    3    7  201800050213B01    4    1      5    1
# 20236  201800050213   0    2    3    7  201800050213B01    4    1      5    1
# 20237  201800050213   0    2    3    7  201800050213B01    4    1      5    1
# 20238  201800050213   0    2    3    7  201800050213B01    4    1      5    1
# 20239  201800050213   0    2    3    7  201800050213B01    4    1      5    1
#
#        ... lum agg int atm col  com                       adr      lat  \
# 20235  ...   1   2   2   2   6  101  12, QUAI FRANCOIS MITTER  4886010
# 20236  ...   1   2   2   2   6  101  12, QUAI FRANCOIS MITTER  4886010
# 20237  ...   1   2   2   2   6  101  12, QUAI FRANCOIS MITTER  4886010
# 20238  ...   1   2   2   2   6  101  12, QUAI FRANCOIS MITTER  4886010
# 20239  ...   1   2   2   2   6  101  12, QUAI FRANCOIS MITTER  4886010
#
#           long  dep
# 20235  0233333  750
# 20236  0233333  750
# 20237  0233333  750
# 20238  0233333  750
# 20239  0233333  750
#
# [5 rows x 36 columns]

# %%
data_filtered_paris.shape
# Out:
# (51050, 36)

# %%
data_filtered_paris.isna().sum()
# Out:
# Num_Acc          0
# obs              0
# obsm             0
# choc             0
# manv             0
# aug              0
# grav             0
# sexe             0
# trajet           0
# secu             0
# locp             0
# an_nais          0
# dup_count        0
# catr             0
# circ             0
# nbv              0
# vosp             0
# prof             0
# plan             0
# surf             0
# infra            0
# situ             0
# an               0
# mois             0
# jour             0
# hrmn             0
# lum              0
# agg              0
# int              0
# atm              0
# col              0
# com              0
# adr              0
# lat          39370
# long         39370
# dep              0
# dtype: int64

# %%
def filter_missing(data, col1, col2):
    """
    Filters a DataFrame to keep only rows where both specified columns have missing values.

    Parameters:
    data (pd.DataFrame): The DataFrame to be filtered.
    col1
    col2

    Returns:
    pd.DataFrame: A DataFrame containing rows where both specified columns have missing values.
    """
    filtered_data = data[data[col1].isna() | data[col2].isna()]
    return filtered_data

# %%
data_filtered_missinglatlong = filter_missing(data_filtered_paris, 'lat', 'long')

# %%
data_filtered_missinglatlong.shape
# Out:
# (39370, 36)

# %%
import re

def remove_comma_period_slash_start(data, column):
    """
    Removes commas, periods, and slashes from the start of each string in the specified column of a DataFrame.

    Parameters:
    data (pd.DataFrame): The DataFrame containing the column to be modified.
    column (str): The name of the column to modify.

    Returns:
    pd.DataFrame: The DataFrame with the specified column modified.
    """

    def clean_string(x):
        # This function uses regex to remove commas, periods, and slashes from the start of the string
        if isinstance(x, str):
            return re.sub(r'^[,.\\/]+', '', x)
        return x

    data[column] = data[column].apply(clean_string)
    return data

# %%
remove_comma_period_slash_start(data_filtered_missinglatlong, 'adr')
# Out:
# /var/folders/jg/x3y4bp6n6071zs7rycbnfsyc0000gn/T/ipykernel_92683/1580107784.py:21: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              Num_Acc obs obsm choc manv              aug grav sexe trajet  \
# 20340   201800050313   0    2    8    1  201800050313B01    4    1      5
# 20341   201800050313   0    2    8    1  201800050313B01    4    1      5
# 20342   201800050313   0    2    8    1  201800050313B01    4    1      5
# 20343   201800050313   0    2    8    1  201800050313B01    4    1      5
# 20344   201800050313   0    2    8    1  201800050313B01    4    1      5
# ...              ...  ..  ...  ...  ...              ...  ...  ...    ...
# 415285  201500056190   0    2    3   15  201500056190A01    4    2      5
# 415286  201500056190   0    2    3   15  201500056190A01    4    2      5
# 415287  201500056190   0    2    3   15  201500056190A01    4    2      5
# 415288  201500056190   0    2    3   15  201500056190A01    4    2      5
# 415289  201500056190   0    2    3   15  201500056190A01    4    2      5
#
#        secu  ... lum agg int atm col  com                       adr  lat long  \
# 20340     1  ...   5   2   2   1   3  109            RUE LA FAYETTE  NaN  NaN
# 20341     1  ...   5   2   2   1   3  109            RUE LA FAYETTE  NaN  NaN
# 20342     1  ...   5   2   2   1   3  109            RUE LA FAYETTE  NaN  NaN
# 20343     1  ...   5   2   2   1   3  109            RUE LA FAYETTE  NaN  NaN
# 20344     1  ...   5   2   2   1   3  109            RUE LA FAYETTE  NaN  NaN
# ...     ...  ...  ..  ..  ..  ..  ..  ...                       ...  ...  ...
# 415285    1  ...   1   2   4   1   3  118  1, AVENUE DE LA PORTE DE  NaN  NaN
# 415286    1  ...   1   2   4   1   3  118  1, AVENUE DE LA PORTE DE  NaN  NaN
# 415287    1  ...   1   2   4   1   3  118  1, AVENUE DE LA PORTE DE  NaN  NaN
# 415288    1  ...   1   2   4   1   3  118  1, AVENUE DE LA PORTE DE  NaN  NaN
# 415289    1  ...   1   2   4   1   3  118  1, AVENUE DE LA PORTE DE  NaN  NaN
#
#         dep
# 20340   750
# 20341   750
# 20342   750
# 20343   750
# 20344   750
# ...     ...
# 415285  750
# 415286  750
# 415287  750
# 415288  750
# 415289  750
#
# [39370 rows x 36 columns]

# %%
filtered_values = data_filtered_missinglatlong[data_filtered_missinglatlong['adr'].str.startswith('/')]
count = len(filtered_values)
print(count)
# Out:
# 0

# %%
data_filtered_missinglatlong.head()
# Out:
#             Num_Acc obs obsm choc manv              aug grav sexe trajet secu  \
# 20340  201800050313   0    2    8    1  201800050313B01    4    1      5    1
# 20341  201800050313   0    2    8    1  201800050313B01    4    1      5    1
# 20342  201800050313   0    2    8    1  201800050313B01    4    1      5    1
# 20343  201800050313   0    2    8    1  201800050313B01    4    1      5    1
# 20344  201800050313   0    2    8    1  201800050313B01    4    1      5    1
#
#        ... lum agg int atm col  com             adr  lat long  dep
# 20340  ...   5   2   2   1   3  109  RUE LA FAYETTE  NaN  NaN  750
# 20341  ...   5   2   2   1   3  109  RUE LA FAYETTE  NaN  NaN  750
# 20342  ...   5   2   2   1   3  109  RUE LA FAYETTE  NaN  NaN  750
# 20343  ...   5   2   2   1   3  109  RUE LA FAYETTE  NaN  NaN  750
# 20344  ...   5   2   2   1   3  109  RUE LA FAYETTE  NaN  NaN  750
#
# [5 rows x 36 columns]

# %%
# def get_lat_lon(address, url='https://api-adresse.data.gouv.fr/search'):

#     params = {'q': address, 'citycode': 75056}
#     r = requests.get(url, params)
#     try: return r.json()['features'][0]['geometry']['coordinates'][::-1]
#     except: print(f'ERROR : {address}, STATUS CODE : {r.status_code}')

# %%
request_count = 0
def get_lat_lon(address, url='https://api-adresse.data.gouv.fr/search'):
    global request_count
    request_count += 1  # Incrémenter le compteur à chaque appel

    params = {'q': address, 'citycode': 75056}
    r = requests.get(url, params)

    try:
        coords = r.json()['features'][0]['geometry']['coordinates'][::-1]
    except:
        print(f'ERROR : {address}, STATUS CODE : {r.status_code}')
        coords = None

    # Vérifier si le compteur a atteint un multiple de 500
    if request_count % 500 == 0:
        print(f'500 requêtes ont été effectuées. Total actuel : {request_count}')

    return coords

# %%
data_filtered_missinglatlong['latlong'] = data_filtered_missinglatlong['adr'].map(lambda address: get_lat_lon(address))
# Out:
# 500 requêtes ont été effectuées. Total actuel : 500
# 500 requêtes ont été effectuées. Total actuel : 1000
# 500 requêtes ont été effectuées. Total actuel : 1500
# 500 requêtes ont été effectuées. Total actuel : 2000
# 500 requêtes ont été effectuées. Total actuel : 2500
# 500 requêtes ont été effectuées. Total actuel : 3000
# ERROR : AVENUE CESAR CAIRE, STATUS CODE : 504
# 500 requêtes ont été effectuées. Total actuel : 3500
# 500 requêtes ont été effectuées. Total actuel : 4000
# ERROR : 16, RUE DE LA FONTAINE A, STATUS CODE : 504
# 500 requêtes ont été effectuées. Total actuel : 4500
# ERROR : SOUTERRAIN GENERAL LEMON, STATUS CODE : 200
# ERROR : SOUTERRAIN GENERAL LEMON, STATUS CODE : 200
# ERROR : SOUTERRAIN GENERAL LEMON, STATUS CODE : 200
# ERROR : SOUTERRAIN GENERAL LEMON, STATUS CODE : 200
# ERROR : SOUTERRAIN GENERAL LEMON, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 5000
# 500 requêtes ont été effectuées. Total actuel : 5500
# 500 requêtes ont été effectuées. Total actuel : 6000
# 500 requêtes ont été effectuées. Total actuel : 6500
# 500 requêtes ont été effectuées. Total actuel : 7000
# ERROR : QUAI DES TUILERIES, STATUS CODE : 504
# 500 requêtes ont été effectuées. Total actuel : 7500
# ERROR : R DES RECOLLETS R FG SAI, STATUS CODE : 200
# ERROR : R DES RECOLLETS R FG SAI, STATUS CODE : 200
# ERROR : R DES RECOLLETS R FG SAI, STATUS CODE : 200
# ERROR : R DES RECOLLETS R FG SAI, STATUS CODE : 200
# ERROR : R DES RECOLLETS R FG SAI, STATUS CODE : 200
# ERROR : AV VERSAILLES R AMIRAL C, STATUS CODE : 200
# ERROR : AV VERSAILLES R AMIRAL C, STATUS CODE : 200
# ERROR : AV VERSAILLES R AMIRAL C, STATUS CODE : 200
# ERROR : AV VERSAILLES R AMIRAL C, STATUS CODE : 200
# ERROR : AV VERSAILLES R AMIRAL C, STATUS CODE : 200
# ERROR : BD V AURIOL R CH DES REN, STATUS CODE : 200
# ERROR : BD V AURIOL R CH DES REN, STATUS CODE : 200
# ERROR : BD V AURIOL R CH DES REN, STATUS CODE : 200
# ERROR : BD V AURIOL R CH DES REN, STATUS CODE : 200
# ERROR : BD V AURIOL R CH DES REN, STATUS CODE : 200
# ERROR : AV DAUMESNIL AV LEDRU RO, STATUS CODE : 200
# ERROR : AV DAUMESNIL AV LEDRU RO, STATUS CODE : 200
# ERROR : AV DAUMESNIL AV LEDRU RO, STATUS CODE : 200
# ERROR : AV DAUMESNIL AV LEDRU RO, STATUS CODE : 200
# ERROR : AV DAUMESNIL AV LEDRU RO, STATUS CODE : 200
# ERROR : L14578 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14578 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14578 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14578 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14578 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14578 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14578 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14578 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14578 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14578 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : PL DE LA BASTILLE R FG S, STATUS CODE : 200
# ERROR : PL DE LA BASTILLE R FG S, STATUS CODE : 200
# ERROR : PL DE LA BASTILLE R FG S, STATUS CODE : 200
# ERROR : PL DE LA BASTILLE R FG S, STATUS CODE : 200
# ERROR : PL DE LA BASTILLE R FG S, STATUS CODE : 200
# ERROR : PT DU GARIGLIANO BD GL M, STATUS CODE : 200
# ERROR : PT DU GARIGLIANO BD GL M, STATUS CODE : 200
# ERROR : PT DU GARIGLIANO BD GL M, STATUS CODE : 200
# ERROR : PT DU GARIGLIANO BD GL M, STATUS CODE : 200
# ERROR : PT DU GARIGLIANO BD GL M, STATUS CODE : 200
# ERROR : R JUSSIEU R FOSS ST BERN, STATUS CODE : 200
# ERROR : R JUSSIEU R FOSS ST BERN, STATUS CODE : 200
# ERROR : R JUSSIEU R FOSS ST BERN, STATUS CODE : 200
# ERROR : R JUSSIEU R FOSS ST BERN, STATUS CODE : 200
# ERROR : R JUSSIEU R FOSS ST BERN, STATUS CODE : 200
# ERROR : AV DE FONTENAY AV DAME B, STATUS CODE : 200
# ERROR : AV DE FONTENAY AV DAME B, STATUS CODE : 200
# ERROR : AV DE FONTENAY AV DAME B, STATUS CODE : 200
# ERROR : AV DE FONTENAY AV DAME B, STATUS CODE : 200
# ERROR : AV DE FONTENAY AV DAME B, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 8000
# ERROR : L14583 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14583 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14583 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14583 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14583 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : R ORDENER R FERDINAND FL, STATUS CODE : 200
# ERROR : R ORDENER R FERDINAND FL, STATUS CODE : 200
# ERROR : R ORDENER R FERDINAND FL, STATUS CODE : 200
# ERROR : R ORDENER R FERDINAND FL, STATUS CODE : 200
# ERROR : R ORDENER R FERDINAND FL, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 8500
# ERROR : L14589 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14589 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14589 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14589 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14589 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : R DE LA CITE Q DE LA COR, STATUS CODE : 200
# ERROR : R DE LA CITE Q DE LA COR, STATUS CODE : 200
# ERROR : R DE LA CITE Q DE LA COR, STATUS CODE : 200
# ERROR : R DE LA CITE Q DE LA COR, STATUS CODE : 200
# ERROR : R DE LA CITE Q DE LA COR, STATUS CODE : 200
# ERROR : CRS DE VINCENNES BD DE C, STATUS CODE : 200
# ERROR : CRS DE VINCENNES BD DE C, STATUS CODE : 200
# ERROR : CRS DE VINCENNES BD DE C, STATUS CODE : 200
# ERROR : CRS DE VINCENNES BD DE C, STATUS CODE : 200
# ERROR : CRS DE VINCENNES BD DE C, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 9000
# ERROR : R DU TEMPLE R DUPETIT TH, STATUS CODE : 200
# ERROR : R DU TEMPLE R DUPETIT TH, STATUS CODE : 200
# ERROR : R DU TEMPLE R DUPETIT TH, STATUS CODE : 200
# ERROR : R DU TEMPLE R DUPETIT TH, STATUS CODE : 200
# ERROR : R DU TEMPLE R DUPETIT TH, STATUS CODE : 200
# ERROR : R DE LOURMEL AV FELIX FA, STATUS CODE : 200
# ERROR : R DE LOURMEL AV FELIX FA, STATUS CODE : 200
# ERROR : R DE LOURMEL AV FELIX FA, STATUS CODE : 200
# ERROR : R DE LOURMEL AV FELIX FA, STATUS CODE : 200
# ERROR : R DE LOURMEL AV FELIX FA, STATUS CODE : 200
# ERROR : R G SAINT HILAIRE R DU F, STATUS CODE : 200
# ERROR : R G SAINT HILAIRE R DU F, STATUS CODE : 200
# ERROR : R G SAINT HILAIRE R DU F, STATUS CODE : 200
# ERROR : R G SAINT HILAIRE R DU F, STATUS CODE : 200
# ERROR : R G SAINT HILAIRE R DU F, STATUS CODE : 200
# ERROR : AV BRUNETIERE SQ DE VAUC, STATUS CODE : 200
# ERROR : AV BRUNETIERE SQ DE VAUC, STATUS CODE : 200
# ERROR : AV BRUNETIERE SQ DE VAUC, STATUS CODE : 200
# ERROR : AV BRUNETIERE SQ DE VAUC, STATUS CODE : 200
# ERROR : AV BRUNETIERE SQ DE VAUC, STATUS CODE : 200
# ERROR : CRS DE VINCENNES BD DE C, STATUS CODE : 200
# ERROR : CRS DE VINCENNES BD DE C, STATUS CODE : 200
# ERROR : CRS DE VINCENNES BD DE C, STATUS CODE : 200
# ERROR : CRS DE VINCENNES BD DE C, STATUS CODE : 200
# ERROR : CRS DE VINCENNES BD DE C, STATUS CODE : 200
# ERROR : CRS DE VINCENNES R DES P, STATUS CODE : 200
# ERROR : CRS DE VINCENNES R DES P, STATUS CODE : 200
# ERROR : CRS DE VINCENNES R DES P, STATUS CODE : 200
# ERROR : CRS DE VINCENNES R DES P, STATUS CODE : 200
# ERROR : CRS DE VINCENNES R DES P, STATUS CODE : 200
# ERROR : R RIVOLI R F DUVAL, STATUS CODE : 200
# ERROR : R RIVOLI R F DUVAL, STATUS CODE : 200
# ERROR : R RIVOLI R F DUVAL, STATUS CODE : 200
# ERROR : R RIVOLI R F DUVAL, STATUS CODE : 200
# ERROR : R RIVOLI R F DUVAL, STATUS CODE : 200
# ERROR : R DES EPINETTES PASS POU, STATUS CODE : 200
# ERROR : R DES EPINETTES PASS POU, STATUS CODE : 200
# ERROR : R DES EPINETTES PASS POU, STATUS CODE : 200
# ERROR : R DES EPINETTES PASS POU, STATUS CODE : 200
# ERROR : R DES EPINETTES PASS POU, STATUS CODE : 200
# ERROR : R COMMINES BD FILLES CAL, STATUS CODE : 200
# ERROR : R COMMINES BD FILLES CAL, STATUS CODE : 200
# ERROR : R COMMINES BD FILLES CAL, STATUS CODE : 200
# ERROR : R COMMINES BD FILLES CAL, STATUS CODE : 200
# ERROR : R COMMINES BD FILLES CAL, STATUS CODE : 200
# ERROR : RTE PT JOUR SURESNES RTE, STATUS CODE : 200
# ERROR : RTE PT JOUR SURESNES RTE, STATUS CODE : 200
# ERROR : RTE PT JOUR SURESNES RTE, STATUS CODE : 200
# ERROR : RTE PT JOUR SURESNES RTE, STATUS CODE : 200
# ERROR : RTE PT JOUR SURESNES RTE, STATUS CODE : 200
# ERROR : RTE PT JOUR SURESNES RTE, STATUS CODE : 200
# ERROR : RTE PT JOUR SURESNES RTE, STATUS CODE : 200
# ERROR : RTE PT JOUR SURESNES RTE, STATUS CODE : 200
# ERROR : RTE PT JOUR SURESNES RTE, STATUS CODE : 200
# ERROR : RTE PT JOUR SURESNES RTE, STATUS CODE : 200
# ERROR : R DU GRAND PRIEURE R J P, STATUS CODE : 200
# ERROR : R DU GRAND PRIEURE R J P, STATUS CODE : 200
# ERROR : R DU GRAND PRIEURE R J P, STATUS CODE : 200
# ERROR : R DU GRAND PRIEURE R J P, STATUS CODE : 200
# ERROR : R DU GRAND PRIEURE R J P, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 9500
# ERROR : R DE CRIMEE R GASTON TES, STATUS CODE : 200
# ERROR : R DE CRIMEE R GASTON TES, STATUS CODE : 200
# ERROR : R DE CRIMEE R GASTON TES, STATUS CODE : 200
# ERROR : R DE CRIMEE R GASTON TES, STATUS CODE : 200
# ERROR : R DE CRIMEE R GASTON TES, STATUS CODE : 200
# ERROR : R BUFFAULT R DU FG MONTM, STATUS CODE : 200
# ERROR : R BUFFAULT R DU FG MONTM, STATUS CODE : 200
# ERROR : R BUFFAULT R DU FG MONTM, STATUS CODE : 200
# ERROR : R BUFFAULT R DU FG MONTM, STATUS CODE : 200
# ERROR : R BUFFAULT R DU FG MONTM, STATUS CODE : 200
# ERROR : PT DE LA CONCORDE Q D OR, STATUS CODE : 200
# ERROR : PT DE LA CONCORDE Q D OR, STATUS CODE : 200
# ERROR : PT DE LA CONCORDE Q D OR, STATUS CODE : 200
# ERROR : PT DE LA CONCORDE Q D OR, STATUS CODE : 200
# ERROR : PT DE LA CONCORDE Q D OR, STATUS CODE : 200
# ERROR : L10184 AV EDOUARD VAILLA, STATUS CODE : 200
# ERROR : L10184 AV EDOUARD VAILLA, STATUS CODE : 200
# ERROR : L10184 AV EDOUARD VAILLA, STATUS CODE : 200
# ERROR : L10184 AV EDOUARD VAILLA, STATUS CODE : 200
# ERROR : L10184 AV EDOUARD VAILLA, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 10000
# ERROR : L14581 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14581 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14581 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14581 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14581 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : CRS LA REINE AV W CHURCH, STATUS CODE : 200
# ERROR : CRS LA REINE AV W CHURCH, STATUS CODE : 200
# ERROR : CRS LA REINE AV W CHURCH, STATUS CODE : 200
# ERROR : CRS LA REINE AV W CHURCH, STATUS CODE : 200
# ERROR : CRS LA REINE AV W CHURCH, STATUS CODE : 200
# ERROR : R GREN ST LAZARE R ST MA, STATUS CODE : 200
# ERROR : R GREN ST LAZARE R ST MA, STATUS CODE : 200
# ERROR : R GREN ST LAZARE R ST MA, STATUS CODE : 200
# ERROR : R GREN ST LAZARE R ST MA, STATUS CODE : 200
# ERROR : R GREN ST LAZARE R ST MA, STATUS CODE : 200
# ERROR : R J PIERRE TIMBAUD R SAI, STATUS CODE : 200
# ERROR : R J PIERRE TIMBAUD R SAI, STATUS CODE : 200
# ERROR : R J PIERRE TIMBAUD R SAI, STATUS CODE : 200
# ERROR : R J PIERRE TIMBAUD R SAI, STATUS CODE : 200
# ERROR : R J PIERRE TIMBAUD R SAI, STATUS CODE : 200
# ERROR : BD JOURDAN R DU PERE COR, STATUS CODE : 200
# ERROR : BD JOURDAN R DU PERE COR, STATUS CODE : 200
# ERROR : BD JOURDAN R DU PERE COR, STATUS CODE : 200
# ERROR : BD JOURDAN R DU PERE COR, STATUS CODE : 200
# ERROR : BD JOURDAN R DU PERE COR, STATUS CODE : 200
# ERROR : AV DE CLICHY R GUY MOQUE, STATUS CODE : 200
# ERROR : AV DE CLICHY R GUY MOQUE, STATUS CODE : 200
# ERROR : AV DE CLICHY R GUY MOQUE, STATUS CODE : 200
# ERROR : AV DE CLICHY R GUY MOQUE, STATUS CODE : 200
# ERROR : AV DE CLICHY R GUY MOQUE, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 10500
# ERROR : n?ant, BOULEVARD DE PORT, STATUS CODE : 200
# ERROR : n?ant, BOULEVARD DE PORT, STATUS CODE : 200
# ERROR : n?ant, BOULEVARD DE PORT, STATUS CODE : 200
# ERROR : n?ant, BOULEVARD DE PORT, STATUS CODE : 200
# ERROR : n?ant, BOULEVARD DE PORT, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 11000
# 500 requêtes ont été effectuées. Total actuel : 11500
# 500 requêtes ont été effectuées. Total actuel : 12000
# 500 requêtes ont été effectuées. Total actuel : 12500
# 500 requêtes ont été effectuées. Total actuel : 13000
# ERROR : 55, RUE GUY MOQUET, STATUS CODE : 504
# 500 requêtes ont été effectuées. Total actuel : 13500
# 500 requêtes ont été effectuées. Total actuel : 14000
# ERROR : 18, RUE DE L HOTEL DE VI, STATUS CODE : 504
# 500 requêtes ont été effectuées. Total actuel : 14500
# 500 requêtes ont été effectuées. Total actuel : 15000
# 500 requêtes ont été effectuées. Total actuel : 15500
# 500 requêtes ont été effectuées. Total actuel : 16000
# ERROR : 82, BOULEVARD MURAT, STATUS CODE : 504
# 500 requêtes ont été effectuées. Total actuel : 16500
# ERROR : VENUE DE LA PORTE DE CL, STATUS CODE : 200
# ERROR : VENUE DE LA PORTE DE CL, STATUS CODE : 200
# ERROR : VENUE DE LA PORTE DE CL, STATUS CODE : 200
# ERROR : VENUE DE LA PORTE DE CL, STATUS CODE : 200
# ERROR : VENUE DE LA PORTE DE CL, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 17000
# 500 requêtes ont été effectuées. Total actuel : 17500
# 500 requêtes ont été effectuées. Total actuel : 18000
# 500 requêtes ont été effectuées. Total actuel : 18500
# 500 requêtes ont été effectuées. Total actuel : 19000
# 500 requêtes ont été effectuées. Total actuel : 19500
# 500 requêtes ont été effectuées. Total actuel : 20000
# 500 requêtes ont été effectuées. Total actuel : 20500
# ERROR : PL DES INVALIDES R P BLE, STATUS CODE : 200
# ERROR : PL DES INVALIDES R P BLE, STATUS CODE : 200
# ERROR : PL DES INVALIDES R P BLE, STATUS CODE : 200
# ERROR : PL DES INVALIDES R P BLE, STATUS CODE : 200
# ERROR : PL DES INVALIDES R P BLE, STATUS CODE : 200
# ERROR : R J BAPT BERLIER BD MASS, STATUS CODE : 200
# ERROR : R J BAPT BERLIER BD MASS, STATUS CODE : 200
# ERROR : R J BAPT BERLIER BD MASS, STATUS CODE : 200
# ERROR : R J BAPT BERLIER BD MASS, STATUS CODE : 200
# ERROR : R J BAPT BERLIER BD MASS, STATUS CODE : 200
# ERROR : RTE DE BOURBON CAR DE PY, STATUS CODE : 200
# ERROR : RTE DE BOURBON CAR DE PY, STATUS CODE : 200
# ERROR : RTE DE BOURBON CAR DE PY, STATUS CODE : 200
# ERROR : RTE DE BOURBON CAR DE PY, STATUS CODE : 200
# ERROR : RTE DE BOURBON CAR DE PY, STATUS CODE : 200
# ERROR : R SOUFFLOT R VICTOR COUS, STATUS CODE : 200
# ERROR : R SOUFFLOT R VICTOR COUS, STATUS CODE : 200
# ERROR : R SOUFFLOT R VICTOR COUS, STATUS CODE : 200
# ERROR : R SOUFFLOT R VICTOR COUS, STATUS CODE : 200
# ERROR : R SOUFFLOT R VICTOR COUS, STATUS CODE : 200
# ERROR : R D ALESIA R AMIRAL MOUC, STATUS CODE : 200
# ERROR : R D ALESIA R AMIRAL MOUC, STATUS CODE : 200
# ERROR : R D ALESIA R AMIRAL MOUC, STATUS CODE : 200
# ERROR : R D ALESIA R AMIRAL MOUC, STATUS CODE : 200
# ERROR : R D ALESIA R AMIRAL MOUC, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 21000
# ERROR : 2 BD BEAUMARCHAIS, STATUS CODE : 504
# ERROR : BD DAVOUT PL PORTE BAGNO, STATUS CODE : 200
# ERROR : BD DAVOUT PL PORTE BAGNO, STATUS CODE : 200
# ERROR : BD DAVOUT PL PORTE BAGNO, STATUS CODE : 200
# ERROR : BD DAVOUT PL PORTE BAGNO, STATUS CODE : 200
# ERROR : BD DAVOUT PL PORTE BAGNO, STATUS CODE : 200
# ERROR : AV DE CLICHY R GUY MOQUE, STATUS CODE : 200
# ERROR : AV DE CLICHY R GUY MOQUE, STATUS CODE : 200
# ERROR : AV DE CLICHY R GUY MOQUE, STATUS CODE : 200
# ERROR : AV DE CLICHY R GUY MOQUE, STATUS CODE : 200
# ERROR : AV DE CLICHY R GUY MOQUE, STATUS CODE : 200
# ERROR : R DEBROUSSE AV DU PDT WI, STATUS CODE : 200
# ERROR : R DEBROUSSE AV DU PDT WI, STATUS CODE : 200
# ERROR : R DEBROUSSE AV DU PDT WI, STATUS CODE : 200
# ERROR : R DEBROUSSE AV DU PDT WI, STATUS CODE : 200
# ERROR : R DEBROUSSE AV DU PDT WI, STATUS CODE : 200
# ERROR : R CARDINET R LEON COGNIE, STATUS CODE : 200
# ERROR : R CARDINET R LEON COGNIE, STATUS CODE : 200
# ERROR : R CARDINET R LEON COGNIE, STATUS CODE : 200
# ERROR : R CARDINET R LEON COGNIE, STATUS CODE : 200
# ERROR : R CARDINET R LEON COGNIE, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 21500
# ERROR : CAR DE PYRAMIDE RTE ROYA, STATUS CODE : 200
# ERROR : CAR DE PYRAMIDE RTE ROYA, STATUS CODE : 200
# ERROR : CAR DE PYRAMIDE RTE ROYA, STATUS CODE : 200
# ERROR : CAR DE PYRAMIDE RTE ROYA, STATUS CODE : 200
# ERROR : CAR DE PYRAMIDE RTE ROYA, STATUS CODE : 200
# ERROR : CAR DE PYRAMIDE RTE ROYA, STATUS CODE : 200
# ERROR : CAR DE PYRAMIDE RTE ROYA, STATUS CODE : 200
# ERROR : CAR DE PYRAMIDE RTE ROYA, STATUS CODE : 200
# ERROR : CAR DE PYRAMIDE RTE ROYA, STATUS CODE : 200
# ERROR : CAR DE PYRAMIDE RTE ROYA, STATUS CODE : 200
# ERROR : R BOUCHARDON R RENE BOUL, STATUS CODE : 200
# ERROR : R BOUCHARDON R RENE BOUL, STATUS CODE : 200
# ERROR : R BOUCHARDON R RENE BOUL, STATUS CODE : 200
# ERROR : R BOUCHARDON R RENE BOUL, STATUS CODE : 200
# ERROR : R BOUCHARDON R RENE BOUL, STATUS CODE : 200
# ERROR : L16222 PL PTE DE SAINT C, STATUS CODE : 200
# ERROR : L16222 PL PTE DE SAINT C, STATUS CODE : 200
# ERROR : L16222 PL PTE DE SAINT C, STATUS CODE : 200
# ERROR : L16222 PL PTE DE SAINT C, STATUS CODE : 200
# ERROR : L16222 PL PTE DE SAINT C, STATUS CODE : 200
# ERROR : BD D INDOCHINE AV PTE BR, STATUS CODE : 200
# ERROR : BD D INDOCHINE AV PTE BR, STATUS CODE : 200
# ERROR : BD D INDOCHINE AV PTE BR, STATUS CODE : 200
# ERROR : BD D INDOCHINE AV PTE BR, STATUS CODE : 200
# ERROR : BD D INDOCHINE AV PTE BR, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 22000
# ERROR : R PT  LOUIS PHILIPPE QU, STATUS CODE : 200
# ERROR : R PT  LOUIS PHILIPPE QU, STATUS CODE : 200
# ERROR : R PT  LOUIS PHILIPPE QU, STATUS CODE : 200
# ERROR : R PT  LOUIS PHILIPPE QU, STATUS CODE : 200
# ERROR : R PT  LOUIS PHILIPPE QU, STATUS CODE : 200
# ERROR : R F DE NEUFCHATEAU R RIC, STATUS CODE : 200
# ERROR : R F DE NEUFCHATEAU R RIC, STATUS CODE : 200
# ERROR : R F DE NEUFCHATEAU R RIC, STATUS CODE : 200
# ERROR : R F DE NEUFCHATEAU R RIC, STATUS CODE : 200
# ERROR : R F DE NEUFCHATEAU R RIC, STATUS CODE : 200
# ERROR : 66 BD DE LA VILLETTE, STATUS CODE : 504
# ERROR : R F DE CROISSET AV PTE, STATUS CODE : 200
# ERROR : R F DE CROISSET AV PTE, STATUS CODE : 200
# ERROR : R F DE CROISSET AV PTE, STATUS CODE : 200
# ERROR : R F DE CROISSET AV PTE, STATUS CODE : 200
# ERROR : R F DE CROISSET AV PTE, STATUS CODE : 200
# ERROR : AV DAUMESNIL ECH PORTE D, STATUS CODE : 200
# ERROR : AV DAUMESNIL ECH PORTE D, STATUS CODE : 200
# ERROR : AV DAUMESNIL ECH PORTE D, STATUS CODE : 200
# ERROR : AV DAUMESNIL ECH PORTE D, STATUS CODE : 200
# ERROR : AV DAUMESNIL ECH PORTE D, STATUS CODE : 200
# ERROR : CRS LA REINE AV W CHURCH, STATUS CODE : 200
# ERROR : CRS LA REINE AV W CHURCH, STATUS CODE : 200
# ERROR : CRS LA REINE AV W CHURCH, STATUS CODE : 200
# ERROR : CRS LA REINE AV W CHURCH, STATUS CODE : 200
# ERROR : CRS LA REINE AV W CHURCH, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 22500
# ERROR : R LECOURBE R VASCO DE GA, STATUS CODE : 200
# ERROR : R LECOURBE R VASCO DE GA, STATUS CODE : 200
# ERROR : R LECOURBE R VASCO DE GA, STATUS CODE : 200
# ERROR : R LECOURBE R VASCO DE GA, STATUS CODE : 200
# ERROR : R LECOURBE R VASCO DE GA, STATUS CODE : 200
# ERROR : L14585 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14585 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14585 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14585 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14585 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14585 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14585 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14585 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14585 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14585 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : AV DE CLICHY R DOCTEUR H, STATUS CODE : 200
# ERROR : AV DE CLICHY R DOCTEUR H, STATUS CODE : 200
# ERROR : AV DE CLICHY R DOCTEUR H, STATUS CODE : 200
# ERROR : AV DE CLICHY R DOCTEUR H, STATUS CODE : 200
# ERROR : AV DE CLICHY R DOCTEUR H, STATUS CODE : 200
# ERROR : AV DAUMESNIL AV LEDRU RO, STATUS CODE : 200
# ERROR : AV DAUMESNIL AV LEDRU RO, STATUS CODE : 200
# ERROR : AV DAUMESNIL AV LEDRU RO, STATUS CODE : 200
# ERROR : AV DAUMESNIL AV LEDRU RO, STATUS CODE : 200
# ERROR : AV DAUMESNIL AV LEDRU RO, STATUS CODE : 200
# ERROR : PT DE GRENELLE PL FERNAN, STATUS CODE : 200
# ERROR : PT DE GRENELLE PL FERNAN, STATUS CODE : 200
# ERROR : PT DE GRENELLE PL FERNAN, STATUS CODE : 200
# ERROR : PT DE GRENELLE PL FERNAN, STATUS CODE : 200
# ERROR : PT DE GRENELLE PL FERNAN, STATUS CODE : 200
# ERROR : R G CHARPENTIER AV PORTE, STATUS CODE : 200
# ERROR : R G CHARPENTIER AV PORTE, STATUS CODE : 200
# ERROR : R G CHARPENTIER AV PORTE, STATUS CODE : 200
# ERROR : R G CHARPENTIER AV PORTE, STATUS CODE : 200
# ERROR : R G CHARPENTIER AV PORTE, STATUS CODE : 200
# ERROR : R D ALESIA R H MAINDRON, STATUS CODE : 200
# ERROR : R D ALESIA R H MAINDRON, STATUS CODE : 200
# ERROR : R D ALESIA R H MAINDRON, STATUS CODE : 200
# ERROR : R D ALESIA R H MAINDRON, STATUS CODE : 200
# ERROR : R D ALESIA R H MAINDRON, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 23000
# ERROR : BD MASSENA AV PORTE DE V, STATUS CODE : 200
# ERROR : BD MASSENA AV PORTE DE V, STATUS CODE : 200
# ERROR : BD MASSENA AV PORTE DE V, STATUS CODE : 200
# ERROR : BD MASSENA AV PORTE DE V, STATUS CODE : 200
# ERROR : BD MASSENA AV PORTE DE V, STATUS CODE : 200
# ERROR : AV E REYER AV PTE DE MON, STATUS CODE : 200
# ERROR : AV E REYER AV PTE DE MON, STATUS CODE : 200
# ERROR : AV E REYER AV PTE DE MON, STATUS CODE : 200
# ERROR : AV E REYER AV PTE DE MON, STATUS CODE : 200
# ERROR : AV E REYER AV PTE DE MON, STATUS CODE : 200
# ERROR : AV E REYER AV PTE DE MON, STATUS CODE : 200
# ERROR : AV E REYER AV PTE DE MON, STATUS CODE : 200
# ERROR : AV E REYER AV PTE DE MON, STATUS CODE : 200
# ERROR : AV E REYER AV PTE DE MON, STATUS CODE : 200
# ERROR : AV E REYER AV PTE DE MON, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 23500
# ERROR : R CI UNIVERSITAIRE BD JO, STATUS CODE : 200
# ERROR : R CI UNIVERSITAIRE BD JO, STATUS CODE : 200
# ERROR : R CI UNIVERSITAIRE BD JO, STATUS CODE : 200
# ERROR : R CI UNIVERSITAIRE BD JO, STATUS CODE : 200
# ERROR : R CI UNIVERSITAIRE BD JO, STATUS CODE : 200
# ERROR : VERD PO NOTRE DAME  PO A, STATUS CODE : 200
# ERROR : VERD PO NOTRE DAME  PO A, STATUS CODE : 200
# ERROR : VERD PO NOTRE DAME  PO A, STATUS CODE : 200
# ERROR : VERD PO NOTRE DAME  PO A, STATUS CODE : 200
# ERROR : VERD PO NOTRE DAME  PO A, STATUS CODE : 200
# ERROR : AV DAUMESNIL AV LEDRU RO, STATUS CODE : 200
# ERROR : AV DAUMESNIL AV LEDRU RO, STATUS CODE : 200
# ERROR : AV DAUMESNIL AV LEDRU RO, STATUS CODE : 200
# ERROR : AV DAUMESNIL AV LEDRU RO, STATUS CODE : 200
# ERROR : AV DAUMESNIL AV LEDRU RO, STATUS CODE : 200
# ERROR : BD PEREIRE PL PORTE MAIL, STATUS CODE : 200
# ERROR : BD PEREIRE PL PORTE MAIL, STATUS CODE : 200
# ERROR : BD PEREIRE PL PORTE MAIL, STATUS CODE : 200
# ERROR : BD PEREIRE PL PORTE MAIL, STATUS CODE : 200
# ERROR : BD PEREIRE PL PORTE MAIL, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 24000
# ERROR : R COMMINES BD FILLES CAL, STATUS CODE : 200
# ERROR : R COMMINES BD FILLES CAL, STATUS CODE : 200
# ERROR : R COMMINES BD FILLES CAL, STATUS CODE : 200
# ERROR : R COMMINES BD FILLES CAL, STATUS CODE : 200
# ERROR : R COMMINES BD FILLES CAL, STATUS CODE : 200
# ERROR : POR DE BOULOGNE ALL REIN, STATUS CODE : 200
# ERROR : POR DE BOULOGNE ALL REIN, STATUS CODE : 200
# ERROR : POR DE BOULOGNE ALL REIN, STATUS CODE : 200
# ERROR : POR DE BOULOGNE ALL REIN, STATUS CODE : 200
# ERROR : POR DE BOULOGNE ALL REIN, STATUS CODE : 200
# ERROR : R DE BERCY AV LEDRU ROLL, STATUS CODE : 200
# ERROR : R DE BERCY AV LEDRU ROLL, STATUS CODE : 200
# ERROR : R DE BERCY AV LEDRU ROLL, STATUS CODE : 200
# ERROR : R DE BERCY AV LEDRU ROLL, STATUS CODE : 200
# ERROR : R DE BERCY AV LEDRU ROLL, STATUS CODE : 200
# ERROR : L4597 JAR TINO ROSSI, STATUS CODE : 200
# ERROR : L4597 JAR TINO ROSSI, STATUS CODE : 200
# ERROR : L4597 JAR TINO ROSSI, STATUS CODE : 200
# ERROR : L4597 JAR TINO ROSSI, STATUS CODE : 200
# ERROR : L4597 JAR TINO ROSSI, STATUS CODE : 200
# ERROR : PL DU CHATELET PO AU CHA, STATUS CODE : 200
# ERROR : PL DU CHATELET PO AU CHA, STATUS CODE : 200
# ERROR : PL DU CHATELET PO AU CHA, STATUS CODE : 200
# ERROR : PL DU CHATELET PO AU CHA, STATUS CODE : 200
# ERROR : PL DU CHATELET PO AU CHA, STATUS CODE : 200
# ERROR : L14585 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14585 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14585 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14585 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : L14585 RTE SEVRES A NEUI, STATUS CODE : 200
# ERROR : PO CHANGE QU DE L HORLOG, STATUS CODE : 200
# ERROR : PO CHANGE QU DE L HORLOG, STATUS CODE : 200
# ERROR : PO CHANGE QU DE L HORLOG, STATUS CODE : 200
# ERROR : PO CHANGE QU DE L HORLOG, STATUS CODE : 200
# ERROR : PO CHANGE QU DE L HORLOG, STATUS CODE : 200
# ERROR : L13446 AV MAL F D ESPERE, STATUS CODE : 200
# ERROR : L13446 AV MAL F D ESPERE, STATUS CODE : 200
# ERROR : L13446 AV MAL F D ESPERE, STATUS CODE : 200
# ERROR : L13446 AV MAL F D ESPERE, STATUS CODE : 200
# ERROR : L13446 AV MAL F D ESPERE, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 24500
# ERROR : PL DE L ALMA PO DE L ALM, STATUS CODE : 200
# ERROR : PL DE L ALMA PO DE L ALM, STATUS CODE : 200
# ERROR : PL DE L ALMA PO DE L ALM, STATUS CODE : 200
# ERROR : PL DE L ALMA PO DE L ALM, STATUS CODE : 200
# ERROR : PL DE L ALMA PO DE L ALM, STATUS CODE : 200
# ERROR : R MANIN AV MATHURIN MORE, STATUS CODE : 200
# ERROR : R MANIN AV MATHURIN MORE, STATUS CODE : 200
# ERROR : R MANIN AV MATHURIN MORE, STATUS CODE : 200
# ERROR : R MANIN AV MATHURIN MORE, STATUS CODE : 200
# ERROR : R MANIN AV MATHURIN MORE, STATUS CODE : 200
# ERROR : PO CHANGE QU DE LA CORSE, STATUS CODE : 200
# ERROR : PO CHANGE QU DE LA CORSE, STATUS CODE : 200
# ERROR : PO CHANGE QU DE LA CORSE, STATUS CODE : 200
# ERROR : PO CHANGE QU DE LA CORSE, STATUS CODE : 200
# ERROR : PO CHANGE QU DE LA CORSE, STATUS CODE : 200
# ERROR : BD MAC DONALD AV PORTE A, STATUS CODE : 200
# ERROR : BD MAC DONALD AV PORTE A, STATUS CODE : 200
# ERROR : BD MAC DONALD AV PORTE A, STATUS CODE : 200
# ERROR : BD MAC DONALD AV PORTE A, STATUS CODE : 200
# ERROR : BD MAC DONALD AV PORTE A, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 25000
# ERROR : VOIE EXPRESS RIVE GAUCHE, STATUS CODE : 200
# ERROR : VOIE EXPRESS RIVE GAUCHE, STATUS CODE : 200
# ERROR : VOIE EXPRESS RIVE GAUCHE, STATUS CODE : 200
# ERROR : VOIE EXPRESS RIVE GAUCHE, STATUS CODE : 200
# ERROR : VOIE EXPRESS RIVE GAUCHE, STATUS CODE : 200
# ERROR : VOIE EXPRESS RIVE GAUCHE, STATUS CODE : 200
# ERROR : VOIE EXPRESS RIVE GAUCHE, STATUS CODE : 200
# ERROR : VOIE EXPRESS RIVE GAUCHE, STATUS CODE : 200
# ERROR : VOIE EXPRESS RIVE GAUCHE, STATUS CODE : 200
# ERROR : VOIE EXPRESS RIVE GAUCHE, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 25500
# 500 requêtes ont été effectuées. Total actuel : 26000
# ERROR : RUE D ALESIA, STATUS CODE : 504
# ERROR : angle, PLACE DENFERT ROC, STATUS CODE : 200
# ERROR : angle, PLACE DENFERT ROC, STATUS CODE : 200
# ERROR : angle, PLACE DENFERT ROC, STATUS CODE : 200
# ERROR : angle, PLACE DENFERT ROC, STATUS CODE : 200
# ERROR : angle, PLACE DENFERT ROC, STATUS CODE : 200
# ERROR : lampadaire, ROUTE DES TR, STATUS CODE : 200
# ERROR : lampadaire, ROUTE DES TR, STATUS CODE : 200
# ERROR : lampadaire, ROUTE DES TR, STATUS CODE : 200
# ERROR : lampadaire, ROUTE DES TR, STATUS CODE : 200
# ERROR : lampadaire, ROUTE DES TR, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 26500
# ERROR : 37, RUE RAFFET, STATUS CODE : 504
# 500 requêtes ont été effectuées. Total actuel : 27000
# 500 requêtes ont été effectuées. Total actuel : 27500
# 500 requêtes ont été effectuées. Total actuel : 28000
# 500 requêtes ont été effectuées. Total actuel : 28500
# 500 requêtes ont été effectuées. Total actuel : 29000
# ERROR : 61, RUE LOUIS BLANC, STATUS CODE : 504
# 500 requêtes ont été effectuées. Total actuel : 29500
# ERROR : 2, RUE DE LA BUTTE AUX C, STATUS CODE : 504
# 500 requêtes ont été effectuées. Total actuel : 30000
# ERROR : SQUARE DE L ASPIRANT DUN, STATUS CODE : 200
# ERROR : SQUARE DE L ASPIRANT DUN, STATUS CODE : 200
# ERROR : SQUARE DE L ASPIRANT DUN, STATUS CODE : 200
# ERROR : SQUARE DE L ASPIRANT DUN, STATUS CODE : 200
# ERROR : SQUARE DE L ASPIRANT DUN, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 30500
# 500 requêtes ont été effectuées. Total actuel : 31000
# ERROR : 34 (face), QUAI DE LA RA, STATUS CODE : 200
# ERROR : 34 (face), QUAI DE LA RA, STATUS CODE : 200
# ERROR : 34 (face), QUAI DE LA RA, STATUS CODE : 200
# ERROR : 34 (face), QUAI DE LA RA, STATUS CODE : 200
# ERROR : 34 (face), QUAI DE LA RA, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 31500
# 500 requêtes ont été effectuées. Total actuel : 32000
# ERROR : 49, RUE SAINT DOMINIQUE, STATUS CODE : 504
# 500 requêtes ont été effectuées. Total actuel : 32500
# 500 requêtes ont été effectuées. Total actuel : 33000
# ERROR : CARREFOUR DE CONSERVATIO, STATUS CODE : 504
# 500 requêtes ont été effectuées. Total actuel : 33500
# 500 requêtes ont été effectuées. Total actuel : 34000
# 500 requêtes ont été effectuées. Total actuel : 34500
# ERROR : 10, RUE RONSARD, STATUS CODE : 504
# 500 requêtes ont été effectuées. Total actuel : 35000
# 500 requêtes ont été effectuées. Total actuel : 35500
# ERROR : --, QUAI DE LA TOURNELLE, STATUS CODE : 400
# ERROR : --, QUAI DE LA TOURNELLE, STATUS CODE : 400
# ERROR : --, QUAI DE LA TOURNELLE, STATUS CODE : 400
# ERROR : --, QUAI DE LA TOURNELLE, STATUS CODE : 400
# ERROR : --, QUAI DE LA TOURNELLE, STATUS CODE : 400
# 500 requêtes ont été effectuées. Total actuel : 36000
# ERROR : --, RUE DES ARCHIVES, STATUS CODE : 400
# ERROR : --, RUE DES ARCHIVES, STATUS CODE : 400
# ERROR : --, RUE DES ARCHIVES, STATUS CODE : 400
# ERROR : --, RUE DES ARCHIVES, STATUS CODE : 400
# ERROR : --, RUE DES ARCHIVES, STATUS CODE : 400
# 500 requêtes ont été effectuées. Total actuel : 36500
# ERROR : VOIE EXPRESS RIVE GAUCHE, STATUS CODE : 200
# ERROR : VOIE EXPRESS RIVE GAUCHE, STATUS CODE : 200
# ERROR : VOIE EXPRESS RIVE GAUCHE, STATUS CODE : 200
# ERROR : VOIE EXPRESS RIVE GAUCHE, STATUS CODE : 200
# ERROR : VOIE EXPRESS RIVE GAUCHE, STATUS CODE : 200
# 500 requêtes ont été effectuées. Total actuel : 37000
# 500 requêtes ont été effectuées. Total actuel : 37500
# 500 requêtes ont été effectuées. Total actuel : 38000
# 500 requêtes ont été effectuées. Total actuel : 38500
# ERROR : 25, RUE GUERSANT, STATUS CODE : 504
# 500 requêtes ont été effectuées. Total actuel : 39000
# /var/folders/jg/x3y4bp6n6071zs7rycbnfsyc0000gn/T/ipykernel_92683/2777418506.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_filtered_missinglatlong['latlong'].isna().sum()
# Out:
# 491

# %%
data_filtered_missinglatlong.to_csv('../clean_data/velo_df_aftercall.csv', index=False)

# %%
data_filtered_missinglatlong['latlong'] = data_filtered_missinglatlong['latlong'].astype(str)

data_filtered_missinglatlong['latlong'] = data_filtered_missinglatlong['latlong'].str.strip('[]').str.replace(' ', '')

data_filtered_missinglatlong[['lat', 'long']] = data_filtered_missinglatlong['latlong'].str.split(',', expand=True)
# Out:
# /var/folders/jg/x3y4bp6n6071zs7rycbnfsyc0000gn/T/ipykernel_92683/3373048785.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/jg/x3y4bp6n6071zs7rycbnfsyc0000gn/T/ipykernel_92683/3373048785.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/jg/x3y4bp6n6071zs7rycbnfsyc0000gn/T/ipykernel_92683/3373048785.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_filtered_missinglatlong.head(2)
# Out:
#             Num_Acc obs obsm choc manv              aug grav sexe trajet secu  \
# 20340  201800050313   0    2    8    1  201800050313B01    4    1      5    1
# 20341  201800050313   0    2    8    1  201800050313B01    4    1      5    1
#
#        ... agg int atm col  com             adr        lat     long  dep  \
# 20340  ...   2   2   1   3  109  RUE LA FAYETTE  48.879907  2.35947  750
# 20341  ...   2   2   1   3  109  RUE LA FAYETTE  48.879907  2.35947  750
#
#                  latlong
# 20340  48.879907,2.35947
# 20341  48.879907,2.35947
#
# [2 rows x 37 columns]

# %%
data_filtered_missinglatlong = data_filtered_missinglatlong.drop(columns=['latlong'], inplace=False)

# %%
data_filtered_missinglatlong.dropna(subset=['lat', 'long'], inplace=True)

# %%
data_filtered_missinglatlong.isna().sum()
# Out:
# Num_Acc      0
# obs          0
# obsm         0
# choc         0
# manv         0
# aug          0
# grav         0
# sexe         0
# trajet       0
# secu         0
# locp         0
# an_nais      0
# dup_count    0
# catr         0
# circ         0
# nbv          0
# vosp         0
# prof         0
# plan         0
# surf         0
# infra        0
# situ         0
# an           0
# mois         0
# jour         0
# hrmn         0
# lum          0
# agg          0
# int          0
# atm          0
# col          0
# com          0
# adr          0
# lat          0
# long         0
# dep          0
# dtype: int64

# %% [markdown]
# ##### Formatage lat long

# %%
"""Formatage non nécessaire ici, le format est bon"""

# def reformatter_lat_lon(dataframe):
#     """
#     Reformate les colonnes de latitude et de longitude d'une DataFrame Pandas,
#     en remplaçant les virgules par des points et en assurant que les valeurs sont dans un format décimal correct.
#     """

#     if 'lat' in dataframe.columns and 'long' in dataframe.columns:
#         for col in ['lat', 'long']:
#             dataframe[col] = pd.to_numeric(dataframe[col].astype(str).str.replace(',', '.'), errors='ignore')
#     else:
#         raise ValueError("La DataFrame doit contenir les colonnes 'lat' et 'long'")

#     return dataframe

# %%
data_filtered_missinglatlong.to_csv('../clean_data/velo_df_paris.csv', index=False)

# %% [markdown]
# # Dataset Pistes

# %%
def get_datasets_url(url):
    response = requests.get(url).json()
    return {el['title']: el['latest'] for el in response['resources'] if el['title'].endswith(".csv") and not el['title'].startswith("vehicules-immatricules")}


def download_and_save_datasets(url_dict, save_path):
    for path, url in url_dict.items():
        full_path = os.path.join(save_path, path)
        if not os.path.exists(full_path):
            response = requests.get(url)
            if response.status_code == 200:
                with open(full_path, 'wb') as f:
                    f.write(response.content)


def rename_files(config_path, save_path):
    with open(config_path, 'r') as f:
        config = yaml.load(f, Loader=yaml.FullLoader)
        rename_config = config.get('rename')

    for old_name, new_name in rename_config.items():
        old_file_path = os.path.join(save_path, old_name)
        new_file_path = os.path.join(save_path, new_name)

        if os.path.exists(old_file_path):
            os.rename(old_file_path, new_file_path)
            print(f"Fichier renommé : {old_name} -> {new_name}")
        else:
            print(f"Fichier non trouvé : {old_name}")

# %%
url = 'https://transport.data.gouv.fr/api/datasets/60a37b7f303fdf4f2654b73d'

# %%
"""Drop colonnes non-pertinentes"""
data_pistes_clean = data_pistes.drop(['num_iti', 'largeur_d', 'local_d', 'largeur_g', 'local_g', 'access_ame', 'statut_d', 'd_service'], axis=1, inplace=False)

# %%
"""Drop Na colonne code_com_d, regime_d, sens_d, ame_d, code_com_g"""
data_pistes_clean = data_pistes_clean.dropna(subset=['code_com_d', 'regime_d', 'sens_d', 'ame_d', 'code_com_g'])

# %%
"""Cleaning colonne lumiere"""
values_distribution_lumiere = data_pistes_clean.lumiere.value_counts(normalize=True)
new_values_lumiere = np.random.choice(values_distribution_lumiere.index, size = data_pistes_clean['lumiere'].isna().sum(), p=values_distribution_lumiere.values)
data_pistes_clean.loc[data_pistes_clean.lumiere.isna(), 'lumiere'] = new_values_lumiere

# %%
"""Cleaning colonne revet_d"""
values_distribution_revet = data_pistes_clean.revet_d.value_counts(normalize=True)
new_values_revet = np.random.choice(values_distribution_revet.index, size = data_pistes_clean['revet_d'].isna().sum(), p=values_distribution_revet.values)
data_pistes_clean.loc[data_pistes_clean.revet_d.isna(), 'revet_d'] = new_values_revet

# %%
"""Cleaning colonne revet_g"""
values_distribution_revetg = data_pistes_clean.revet_g.value_counts(normalize=True)
new_values_revetg = np.random.choice(values_distribution_revetg.index, size = data_pistes_clean['revet_g'].isna().sum(), p=values_distribution_revetg.values)
data_pistes_clean.loc[data_pistes_clean.revet_g.isna(), 'revet_g'] = new_values_revetg

# %%
"""Cleaning colonne regime_g"""
values_distribution_regimeg = data_pistes_clean.regime_g.value_counts(normalize=True)
new_values_regimeg = np.random.choice(values_distribution_regimeg.index, size = data_pistes_clean['regime_g'].isna().sum(), p=values_distribution_regimeg.values)
data_pistes_clean.loc[data_pistes_clean.regime_g.isna(), 'regime_g'] = new_values_regimeg

# %%
"""Cleaning colonne sens_g"""
values_distribution_sensg = data_pistes_clean.sens_g.value_counts(normalize=True)
new_values_sensg = np.random.choice(values_distribution_sensg.index, size = data_pistes_clean['sens_g'].isna().sum(), p=values_distribution_sensg.values)
data_pistes_clean.loc[data_pistes_clean.sens_g.isna(), 'sens_g'] = new_values_sensg

# %%
"""Cleaning colonne trafic_vit"""
values_distribution_trafic = data_pistes_clean.trafic_vit.value_counts(normalize=True)
new_values_trafic = np.random.choice(values_distribution_trafic.index, size = data_pistes_clean['trafic_vit'].isna().sum(), p=values_distribution_trafic.values)
data_pistes_clean.loc[data_pistes_clean.trafic_vit.isna(), 'trafic_vit'] = new_values_trafic

# %% [markdown]
# # Data Flux

# %%
fichier_compteurs = '/Users/aurelienbrame/code/CyclingFacilities/raw_data/Flux/comptage-velo-compteurs.geojson'
fichier_compteurs_data = '/Users/aurelienbrame/code/CyclingFacilities/raw_data/Flux/comptage-velo-donnees-compteurs.geojson'

# %%
data_flux_compteurs = gpd.read_file(fichier_compteurs)
data_flux_compteurs_data = gpd.read_file(fichier_compteurs_data)

# %%
data_flux_compteurs_data.head()

# %%
data_flux_compteurs_data.columns

# %%
data_flux_compteurs_data.drop(['url_photos_n1', 'type_dimage', 'photos', 'id_photo_1',
                               'test_lien_vers_photos_du_site_de_comptage_', 'url_sites',
                               'coordinates', 'name', 'id'],
                              axis=1, inplace=False)

# %%
data_flux_months = pd.to_datetime(data_flux_compteurs_data['date'])
counts_by_month = data_flux_compteurs_data.groupby(data_flux_compteurs_data['date'].dt.to_period('M')).sum()
counts_by_month
